# %%
# => load file lain
from ipynb.fs.full.praproses_data import *
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB
# (2256, 60) (2256,)
# (520, 60) (520,)
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ### 4. Modeling LSTM-RNN

# %%
# The LSTM-RNN architecture
model = tf.keras.Sequential([
    
    # First LSTM layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound LSTM layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model LSTM
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history = model.fit(x_train, y_train, batch_size=8, epochs=50, verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 10s 17ms/step - loss: 0.0010
# Epoch 2/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0029
# Epoch 3/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0037
# Epoch 4/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0023
# Epoch 5/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.4431e-04
# Epoch 6/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0011
# Epoch 7/50
# 282/282 [==============================] - 5s 16ms/step - loss: 3.8726e-04
# Epoch 8/50
# 282/282 [==============================] - 5s 16ms/step - loss: 2.4451e-04
# Epoch 9/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.7619e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.5779e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.5283e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.5026e-04
# Epoch 13/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4963e-04
# Epoch 14/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5008e-04
# Epoch 15/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.5058e-04
# Epoch 16/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5077e-04
# Epoch 17/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5069e-04
# Epoch 18/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5026e-04
# Epoch 19/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4964e-04
# Epoch 20/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4896e-04
# Epoch 21/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.4822e-04
# Epoch 22/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4729e-04
# Epoch 23/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.4601e-04
# Epoch 24/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.4436e-04
# Epoch 25/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4243e-04
# Epoch 26/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4037e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3830e-04
# Epoch 28/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3628e-04
# Epoch 29/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3437e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3244e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3056e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.2888e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.2702e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.2899e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.2736e-04
# Epoch 36/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2620e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.2699e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1717e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2224e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4867e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.8197e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.9532e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.9074e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5132e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.1678e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0586e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.8494e-05
# Epoch 48/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.4723e-05
# Epoch 49/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.1654e-05
# Epoch 50/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.5715e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 60, 100)             20800
#  l)
#
#  bidirectional_1 (Bidirectio  (8, 100)                 60400
#  nal)
#
#  dense (Dense)               (8, 1)                    101
#
# =================================================================
# Total params: 81,301
# Trainable params: 81,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions = model.predict(x_test)
# Out:
# 17/17 [==============================] - 2s 10ms/step

# %%
print(predictions[:7])
# Out:
# [[0.54862773]
#  [0.5572594 ]
#  [0.5295168 ]
#  [0.58180887]
#  [0.5996604 ]
#  [0.5998873 ]
#  [0.5648789 ]]

# %%
# make frame
fig, ax = plt.subplots(figsize = (10,5))

# make time series plot
ax.plot(history.history['loss'], color="tab:blue", label="loss func", linewidth=2)

# make labels
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# show plot
plt.show()

# %% [markdown]
# ### 5. Evaluation Model LSTM-RNN

# %%
scores = model.evaluate(x_train, y_train)
scores
# Out:
# 71/71 [==============================] - 2s 11ms/step - loss: 6.7149e-04
# 0.0006714859046041965

# %%
scores = model.evaluate(x_test, y_test)
scores
# Out:
# 17/17 [==============================] - 0s 11ms/step - loss: 5.0161e-04
# 0.0005016119102947414

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae = mean_absolute_error(y_test, predictions) * 100
print('Test MAE : %.2f' % mae)
# Out:
# Test MAE : 1.67

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse = mean_squared_error(y_test, predictions) * 100
print('Test MSE: %.2f' % mse)
# Out:
# Test MSE: 0.05

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse = sqrt(mse) * 100
print('Test RMSE: %.2f' % rmse)
# Out:
# Test RMSE: 22.40

# %% [markdown]
# - MAPE (Absolute Percentage Error)

# %%
mape = mean_absolute_percentage_error(y_test, predictions) * 100
print('Test MAPE: %.2f' % mape)
# Out:
# Test MAPE: 3.15

# %% [markdown]
# - Corelation pearson

# %%
hasil = np.stack((y_test.reshape(-1), predictions.reshape(-1)), axis=1)
hasil = pd.DataFrame(hasil, columns = ['data_aktual','prediksi'])
hasil.head()
# Out:
#    data_aktual  prediksi
# 0     0.551373  0.548628
# 1     0.524931  0.557259
# 2     0.577541  0.529517
# 3     0.594170  0.581809
# 4     0.596957  0.599660

# %%
r, p = sc.pearsonr(hasil["data_aktual"], hasil["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r)+ "dengan signifikansi" +" {:.4f} ".format(p))
# Out:
# korelasi data akual dengan hasil prediksi 0.9938 dengan signifikansi 0.0000

# %% [markdown]
# - Complexity time

# %%
# Final set of computation time 
end = time.time()

# %%
# Process computation time
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Results computation time 
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:04:24.24

# %% [markdown]
# ### 6. Data Visualization

# %%
# make frame
fig, ax = plt.subplots(figsize = (10,5))

# make time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions, color="tab:red", label="data prediksi", linewidth=2.5)

# makes label-label
ax.set_title("Model Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

plt.show()

# %%
# inverse value test predictions
testPredictions = scaler.inverse_transform(predictions)

# %%
# shift test predictions for plotting
testPredictionsPlot = np.empty_like(scaled_data)
testPredictionsPlot[:, :] = np.nan
testPredictionsPlot[(len(dataset) - testPredictions.shape[0]):len(dataset), :] = testPredictions

# %%
# make frame
fig, ax = plt.subplots(figsize = (15,5))

# make time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2)
ax.plot(dataset.index.values, testPredictionsPlot, color="tab:red", label="data prediksi", linewidth=2)

# make label-label
ax.set_title("Model Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# show plot
plt.show()
