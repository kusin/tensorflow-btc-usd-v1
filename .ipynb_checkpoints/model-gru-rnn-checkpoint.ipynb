# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 4s 11ms/step - loss: 0.0014 - val_loss: 0.0244
# Epoch 2/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0041 - val_loss: 0.0419
# Epoch 3/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 4/50
# 282/282 [==============================] - 3s 9ms/step - loss: 4.1979e-04 - val_loss: 7.2136e-04
# Epoch 5/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.2357e-05 - val_loss: 8.1665e-04
# Epoch 6/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.7188e-05 - val_loss: 8.5998e-04
# Epoch 7/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.0089e-04 - val_loss: 9.0951e-04
# Epoch 8/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.0590e-04 - val_loss: 9.6314e-04
# Epoch 9/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.1199e-04 - val_loss: 0.0010
# Epoch 10/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.1822e-04 - val_loss: 0.0010
# Epoch 11/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.2304e-04 - val_loss: 0.0011
# Epoch 12/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.2441e-04 - val_loss: 0.0010
# Epoch 13/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.2059e-04 - val_loss: 9.7455e-04
# Epoch 14/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.1152e-04 - val_loss: 8.9074e-04
# Epoch 15/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.9856e-05 - val_loss: 8.0683e-04
# Epoch 16/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.9790e-05 - val_loss: 7.5018e-04
# Epoch 17/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.4121e-05 - val_loss: 7.3291e-04
# Epoch 18/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.2652e-05 - val_loss: 7.3751e-04
# Epoch 19/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.3218e-05 - val_loss: 7.4476e-04
# Epoch 20/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.4208e-05 - val_loss: 7.4748e-04
# Epoch 21/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.5012e-05 - val_loss: 7.4381e-04
# Epoch 22/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.5405e-05 - val_loss: 7.3404e-04
# Epoch 23/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.5338e-05 - val_loss: 7.1964e-04
# Epoch 24/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.4871e-05 - val_loss: 7.0250e-04
# Epoch 25/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.4112e-05 - val_loss: 6.8436e-04
# Epoch 26/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.3179e-05 - val_loss: 6.6663e-04
# Epoch 27/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.2180e-05 - val_loss: 6.5028e-04
# Epoch 28/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.1193e-05 - val_loss: 6.3589e-04
# Epoch 29/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.0279e-05 - val_loss: 6.2379e-04
# Epoch 30/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.9473e-05 - val_loss: 6.1407e-04
# Epoch 31/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8791e-05 - val_loss: 6.0672e-04
# Epoch 32/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8206e-05 - val_loss: 6.0160e-04
# Epoch 33/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7630e-05 - val_loss: 5.9884e-04
# Epoch 34/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7493e-05 - val_loss: 5.9750e-04
# Epoch 35/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7331e-05 - val_loss: 5.9785e-04
# Epoch 36/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7177e-05 - val_loss: 5.9954e-04
# Epoch 37/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7217e-05 - val_loss: 6.0226e-04
# Epoch 38/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7294e-05 - val_loss: 6.0535e-04
# Epoch 39/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7418e-05 - val_loss: 6.0842e-04
# Epoch 40/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7132e-05 - val_loss: 6.1571e-04
# Epoch 41/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7755e-05 - val_loss: 6.1691e-04
# Epoch 42/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7724e-05 - val_loss: 6.2307e-04
# Epoch 43/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7796e-05 - val_loss: 6.3022e-04
# Epoch 44/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8267e-05 - val_loss: 6.3073e-04
# Epoch 45/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7556e-05 - val_loss: 6.3154e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7648e-05 - val_loss: 6.3469e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7472e-05 - val_loss: 6.3674e-04
# Epoch 48/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7316e-05 - val_loss: 6.3914e-04
# Epoch 49/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6972e-05 - val_loss: 6.4201e-04
# Epoch 50/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6774e-05 - val_loss: 6.4735e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.5574386 ]
#  [0.56810665]
#  [0.5389372 ]
#  [0.593138  ]
#  [0.6075288 ]
#  [0.6119242 ]
#  [0.5791343 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 4ms/step - loss: 7.5854e-04
# 0.0007585439598187804

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 6.4735e-04
# 0.0006473522516898811

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0208

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0006

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0254

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.557439
# 1       0.524931  0.568107
# 2       0.577541  0.538937
# 3       0.594170  0.593138
# 4       0.596957  0.607529
# ..           ...       ...
# 515     0.272496  0.325455
# 516     0.233016  0.295266
# 517     0.258332  0.256297
# 518     0.250134  0.279558
# 519     0.245951  0.273065
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 8s 19ms/step - loss: 6.7937e-04 - val_loss: 0.0225
# Epoch 2/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0031 - val_loss: 0.0220
# Epoch 3/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0042 - val_loss: 0.0253
# Epoch 4/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0040 - val_loss: 0.0296
# Epoch 5/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0040 - val_loss: 0.0243
# Epoch 6/50
# 282/282 [==============================] - 5s 16ms/step - loss: 0.0036 - val_loss: 0.0406
# Epoch 7/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0028 - val_loss: 0.0267
# Epoch 8/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0014 - val_loss: 0.0103
# Epoch 9/50
# 282/282 [==============================] - 5s 16ms/step - loss: 4.3577e-04 - val_loss: 0.0011
# Epoch 10/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.2663e-05 - val_loss: 6.6366e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.1041e-05 - val_loss: 6.1616e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.7875e-05 - val_loss: 6.1497e-04
# Epoch 13/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.4214e-05 - val_loss: 6.4078e-04
# Epoch 14/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.2757e-05 - val_loss: 6.9292e-04
# Epoch 15/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.3663e-05 - val_loss: 7.6659e-04
# Epoch 16/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.5994e-05 - val_loss: 8.4733e-04
# Epoch 17/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.8629e-05 - val_loss: 9.2284e-04
# Epoch 18/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.1246e-05 - val_loss: 9.9837e-04
# Epoch 19/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.4301e-05 - val_loss: 0.0011
# Epoch 20/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.7323e-05 - val_loss: 0.0011
# Epoch 21/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.0136e-05 - val_loss: 0.0010
# Epoch 22/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.3145e-05 - val_loss: 9.6406e-04
# Epoch 23/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.7245e-05 - val_loss: 8.8918e-04
# Epoch 24/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.2141e-05 - val_loss: 8.1553e-04
# Epoch 25/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.6595e-05 - val_loss: 7.5030e-04
# Epoch 26/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.9787e-05 - val_loss: 6.9426e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0170e-04 - val_loss: 6.4335e-04
# Epoch 28/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0276e-04 - val_loss: 5.9380e-04
# Epoch 29/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0325e-04 - val_loss: 5.4538e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0328e-04 - val_loss: 5.0066e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0284e-04 - val_loss: 4.6308e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0186e-04 - val_loss: 4.3575e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0035e-04 - val_loss: 4.2027e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.8393e-05 - val_loss: 4.1562e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.6200e-05 - val_loss: 4.1855e-04
# Epoch 36/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.4003e-05 - val_loss: 4.2525e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.1985e-05 - val_loss: 4.3275e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.0257e-05 - val_loss: 4.3968e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.8919e-05 - val_loss: 4.4831e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.7690e-05 - val_loss: 4.5090e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.6988e-05 - val_loss: 4.6088e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.5934e-05 - val_loss: 4.5713e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.6910e-05 - val_loss: 4.4905e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.8170e-05 - val_loss: 4.4657e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.1307e-05 - val_loss: 4.8658e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.9046e-05 - val_loss: 4.8578e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.9188e-05 - val_loss: 5.4215e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.2988e-05 - val_loss: 5.3760e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.8953e-05 - val_loss: 4.6166e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.1784e-05 - val_loss: 4.1800e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 8ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.537537  ]
#  [0.5453164 ]
#  [0.5183273 ]
#  [0.57142967]
#  [0.5894914 ]
#  [0.5912023 ]
#  [0.55923074]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 8ms/step - loss: 4.5986e-04
# 0.00045986039913259447

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 8ms/step - loss: 4.1800e-04
# 0.0004180033574812114

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0144

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0204

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.537537
# 1       0.524931  0.545316
# 2       0.577541  0.518327
# 3       0.594170  0.571430
# 4       0.596957  0.589491
# ..           ...       ...
# 515     0.272496  0.300468
# 516     0.233016  0.271842
# 517     0.258332  0.236916
# 518     0.250134  0.262020
# 519     0.245951  0.251288
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9945 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 6s 12ms/step - loss: 7.8961e-04 - val_loss: 0.0260
# Epoch 2/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0030 - val_loss: 0.0251
# Epoch 3/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0021 - val_loss: 0.0271
# Epoch 4/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0019 - val_loss: 0.0266
# Epoch 5/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0015 - val_loss: 0.0215
# Epoch 6/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0010 - val_loss: 0.0125
# Epoch 7/50
# 282/282 [==============================] - 3s 10ms/step - loss: 5.3597e-04 - val_loss: 0.0068
# Epoch 8/50
# 282/282 [==============================] - 3s 10ms/step - loss: 2.5654e-04 - val_loss: 0.0033
# Epoch 9/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3086e-04 - val_loss: 0.0025
# Epoch 10/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.0992e-04 - val_loss: 0.0022
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.0392e-04 - val_loss: 0.0021
# Epoch 12/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.9848e-05 - val_loss: 0.0020
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.4994e-05 - val_loss: 0.0019
# Epoch 14/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.8913e-05 - val_loss: 0.0018
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.2358e-05 - val_loss: 0.0018
# Epoch 16/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6574e-05 - val_loss: 0.0019
# Epoch 17/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2829e-05 - val_loss: 0.0020
# Epoch 18/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1478e-05 - val_loss: 0.0021
# Epoch 19/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1933e-05 - val_loss: 0.0023
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3359e-05 - val_loss: 0.0024
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5167e-05 - val_loss: 0.0024
# Epoch 22/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6967e-05 - val_loss: 0.0025
# Epoch 23/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8504e-05 - val_loss: 0.0024
# Epoch 24/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9745e-05 - val_loss: 0.0023
# Epoch 25/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0761e-05 - val_loss: 0.0022
# Epoch 26/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1596e-05 - val_loss: 0.0021
# Epoch 27/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.2222e-05 - val_loss: 0.0020
# Epoch 28/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.2591e-05 - val_loss: 0.0019
# Epoch 29/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.2689e-05 - val_loss: 0.0019
# Epoch 30/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.2555e-05 - val_loss: 0.0018
# Epoch 31/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.2261e-05 - val_loss: 0.0017
# Epoch 32/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.1871e-05 - val_loss: 0.0017
# Epoch 33/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1424e-05 - val_loss: 0.0016
# Epoch 34/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0869e-05 - val_loss: 0.0016
# Epoch 35/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0388e-05 - val_loss: 0.0015
# Epoch 36/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0007e-05 - val_loss: 0.0015
# Epoch 37/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9944e-05 - val_loss: 0.0015
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0220e-05 - val_loss: 0.0015
# Epoch 39/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9583e-05 - val_loss: 0.0015
# Epoch 40/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9367e-05 - val_loss: 0.0015
# Epoch 41/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9363e-05 - val_loss: 0.0015
# Epoch 42/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9373e-05 - val_loss: 0.0014
# Epoch 43/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8849e-05 - val_loss: 0.0014
# Epoch 44/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8675e-05 - val_loss: 0.0014
# Epoch 45/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8688e-05 - val_loss: 0.0014
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7934e-05 - val_loss: 0.0014
# Epoch 47/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6652e-05 - val_loss: 0.0014
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6784e-05 - val_loss: 0.0014
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6401e-05 - val_loss: 0.0014
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5773e-05 - val_loss: 0.0014

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.5895697 ]
#  [0.60022527]
#  [0.57241815]
#  [0.62401557]
#  [0.63826233]
#  [0.6398932 ]
#  [0.6064575 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.6158e-04
# 0.0007615801296196878

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014
# 0.001423972425982356

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0332

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0014

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0377

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.589570
# 1       0.524931  0.600225
# 2       0.577541  0.572418
# 3       0.594170  0.624016
# 4       0.596957  0.638262
# ..           ...       ...
# 515     0.272496  0.335232
# 516     0.233016  0.305242
# 517     0.258332  0.266498
# 518     0.250134  0.290916
# 519     0.245951  0.283379
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9936 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 12s 22ms/step - loss: 7.0817e-04 - val_loss: 0.0159
# Epoch 2/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0025 - val_loss: 0.0217
# Epoch 3/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0035 - val_loss: 0.0073
# Epoch 4/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0018 - val_loss: 0.0041
# Epoch 5/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 6/50
# 282/282 [==============================] - 5s 19ms/step - loss: 6.0641e-04 - val_loss: 0.0013
# Epoch 7/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.5097e-04 - val_loss: 8.4601e-04
# Epoch 8/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0468e-04 - val_loss: 6.6275e-04
# Epoch 9/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.0289e-05 - val_loss: 5.3139e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.1368e-05 - val_loss: 5.0534e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 19ms/step - loss: 7.8615e-05 - val_loss: 6.0919e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 19ms/step - loss: 7.8576e-05 - val_loss: 9.2072e-04
# Epoch 13/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.3281e-05 - val_loss: 0.0016
# Epoch 14/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.5205e-05 - val_loss: 0.0024
# Epoch 15/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1311e-04 - val_loss: 0.0025
# Epoch 16/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2204e-04 - val_loss: 0.0025
# Epoch 17/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2575e-04 - val_loss: 0.0024
# Epoch 18/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2767e-04 - val_loss: 0.0024
# Epoch 19/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2907e-04 - val_loss: 0.0024
# Epoch 20/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2982e-04 - val_loss: 0.0025
# Epoch 21/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2877e-04 - val_loss: 0.0025
# Epoch 22/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2836e-04 - val_loss: 0.0023
# Epoch 23/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2668e-04 - val_loss: 0.0019
# Epoch 24/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2862e-04 - val_loss: 0.0018
# Epoch 25/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2944e-04 - val_loss: 0.0016
# Epoch 26/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3233e-04 - val_loss: 0.0015
# Epoch 27/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3662e-04 - val_loss: 0.0013
# Epoch 28/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3851e-04 - val_loss: 0.0011
# Epoch 29/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3846e-04 - val_loss: 9.0373e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3888e-04 - val_loss: 8.1346e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3474e-04 - val_loss: 8.1001e-04
# Epoch 32/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2902e-04 - val_loss: 9.9592e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2039e-04 - val_loss: 0.0011
# Epoch 34/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1587e-04 - val_loss: 0.0011
# Epoch 35/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1719e-04 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1727e-04 - val_loss: 9.8092e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2479e-04 - val_loss: 8.3640e-04
# Epoch 38/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.4151e-04 - val_loss: 6.9984e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.6276e-04 - val_loss: 4.6595e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.8281e-04 - val_loss: 4.6410e-04
# Epoch 41/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.7340e-04 - val_loss: 4.4933e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.7094e-04 - val_loss: 4.3178e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5057e-04 - val_loss: 4.5249e-04
# Epoch 44/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2402e-04 - val_loss: 5.5423e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0582e-04 - val_loss: 6.7574e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.0141e-04 - val_loss: 7.5292e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 20ms/step - loss: 9.9946e-05 - val_loss: 7.4672e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.9437e-05 - val_loss: 6.4848e-04
# Epoch 49/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.0586e-04 - val_loss: 5.6668e-04
# Epoch 50/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2452e-04 - val_loss: 5.2387e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 11ms/step
# [[0.5601402 ]
#  [0.57067543]
#  [0.5430306 ]
#  [0.5951034 ]
#  [0.6098732 ]
#  [0.61198014]
#  [0.5797325 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 9ms/step - loss: 0.0020
# 0.0020204398315399885

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 9ms/step - loss: 5.2387e-04
# 0.0005238676676526666

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0174

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0005

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0229

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.560140
# 1       0.524931  0.570675
# 2       0.577541  0.543031
# 3       0.594170  0.595103
# 4       0.596957  0.609873
# ..           ...       ...
# 515     0.272496  0.311562
# 516     0.233016  0.284527
# 517     0.258332  0.249994
# 518     0.250134  0.275040
# 519     0.245951  0.264953
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9941 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.020764  0.000647  0.025443
# 1  Percobaan 2  0.014445  0.000418  0.020445
# 2  Percobaan 3  0.033203  0.001424  0.037736
# 3  Percobaan 4  0.017405  0.000524  0.022888

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %%
##### membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:13:22.80
