# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 4s 10ms/step - loss: 8.9217e-04 - val_loss: 0.0159
# Epoch 2/50
# 282/282 [==============================] - 2s 8ms/step - loss: 0.0026 - val_loss: 0.0225
# Epoch 3/50
# 282/282 [==============================] - 2s 8ms/step - loss: 0.0017 - val_loss: 0.0132
# Epoch 4/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.2348e-04 - val_loss: 0.0033
# Epoch 5/50
# 282/282 [==============================] - 2s 8ms/step - loss: 2.2570e-04 - val_loss: 8.9195e-04
# Epoch 6/50
# 282/282 [==============================] - 2s 9ms/step - loss: 9.4184e-05 - val_loss: 7.5994e-04
# Epoch 7/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.9055e-05 - val_loss: 7.6504e-04
# Epoch 8/50
# 282/282 [==============================] - 2s 8ms/step - loss: 9.2021e-05 - val_loss: 7.9720e-04
# Epoch 9/50
# 282/282 [==============================] - 2s 8ms/step - loss: 9.7454e-05 - val_loss: 8.3773e-04
# Epoch 10/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.0379e-04 - val_loss: 8.7291e-04
# Epoch 11/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.0906e-04 - val_loss: 8.8878e-04
# Epoch 12/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.1084e-04 - val_loss: 8.7413e-04
# Epoch 13/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.0734e-04 - val_loss: 8.2735e-04
# Epoch 14/50
# 282/282 [==============================] - 2s 9ms/step - loss: 9.8988e-05 - val_loss: 7.6134e-04
# Epoch 15/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.8968e-05 - val_loss: 6.9919e-04
# Epoch 16/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.1156e-05 - val_loss: 6.6398e-04
# Epoch 17/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7421e-05 - val_loss: 6.6182e-04
# Epoch 18/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7055e-05 - val_loss: 6.7606e-04
# Epoch 19/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.8163e-05 - val_loss: 6.9204e-04
# Epoch 20/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9524e-05 - val_loss: 7.0386e-04
# Epoch 21/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.0637e-05 - val_loss: 7.0980e-04
# Epoch 22/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.1318e-05 - val_loss: 7.1018e-04
# Epoch 23/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.1556e-05 - val_loss: 7.0642e-04
# Epoch 24/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.1433e-05 - val_loss: 7.0029e-04
# Epoch 25/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.1071e-05 - val_loss: 6.9337e-04
# Epoch 26/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.0584e-05 - val_loss: 6.8683e-04
# Epoch 27/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0065e-05 - val_loss: 6.8135e-04
# Epoch 28/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.9576e-05 - val_loss: 6.7724e-04
# Epoch 29/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.9144e-05 - val_loss: 6.7449e-04
# Epoch 30/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8694e-05 - val_loss: 6.7296e-04
# Epoch 31/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8298e-05 - val_loss: 6.7281e-04
# Epoch 32/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.8134e-05 - val_loss: 6.7466e-04
# Epoch 33/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7873e-05 - val_loss: 6.7627e-04
# Epoch 34/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7775e-05 - val_loss: 6.8077e-04
# Epoch 35/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7742e-05 - val_loss: 6.8518e-04
# Epoch 36/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7663e-05 - val_loss: 6.8963e-04
# Epoch 37/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7499e-05 - val_loss: 6.9535e-04
# Epoch 38/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7453e-05 - val_loss: 7.0480e-04
# Epoch 39/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7894e-05 - val_loss: 7.0917e-04
# Epoch 40/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7429e-05 - val_loss: 7.1425e-04
# Epoch 41/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7464e-05 - val_loss: 7.1982e-04
# Epoch 42/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7275e-05 - val_loss: 7.2688e-04
# Epoch 43/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7476e-05 - val_loss: 7.2737e-04
# Epoch 44/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.6574e-05 - val_loss: 7.3301e-04
# Epoch 45/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.6745e-05 - val_loss: 7.3659e-04
# Epoch 46/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6284e-05 - val_loss: 7.3974e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5894e-05 - val_loss: 7.4591e-04
# Epoch 48/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5716e-05 - val_loss: 7.5027e-04
# Epoch 49/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5534e-05 - val_loss: 7.5940e-04
# Epoch 50/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5457e-05 - val_loss: 7.6234e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.56211466]
#  [0.57244956]
#  [0.5431433 ]
#  [0.59711653]
#  [0.6121923 ]
#  [0.61627394]
#  [0.5831574 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 4ms/step - loss: 8.0403e-04
# 0.0008040326647460461

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 7.6234e-04
# 0.000762336771003902

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0231

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0008

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0276

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.562115
# 1       0.524931  0.572450
# 2       0.577541  0.543143
# 3       0.594170  0.597117
# 4       0.596957  0.612192
# ..           ...       ...
# 515     0.272496  0.329141
# 516     0.233016  0.298686
# 517     0.258332  0.259063
# 518     0.250134  0.282051
# 519     0.245951  0.276160
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 8s 18ms/step - loss: 6.8320e-04 - val_loss: 0.0217
# Epoch 2/50
# 282/282 [==============================] - 5s 16ms/step - loss: 0.0034 - val_loss: 0.0227
# Epoch 3/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0048 - val_loss: 0.0351
# Epoch 4/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0046 - val_loss: 0.0382
# Epoch 5/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0039 - val_loss: 0.0292
# Epoch 6/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0031 - val_loss: 0.0379
# Epoch 7/50
# 282/282 [==============================] - 5s 16ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 8/50
# 282/282 [==============================] - 5s 16ms/step - loss: 2.0401e-04 - val_loss: 6.7021e-04
# Epoch 9/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.7076e-05 - val_loss: 5.8701e-04
# Epoch 10/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.3817e-05 - val_loss: 5.8909e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.3623e-05 - val_loss: 6.0850e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.4032e-05 - val_loss: 6.4274e-04
# Epoch 13/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.5090e-05 - val_loss: 6.9165e-04
# Epoch 14/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.6762e-05 - val_loss: 7.5163e-04
# Epoch 15/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.8814e-05 - val_loss: 8.0977e-04
# Epoch 16/50
# 282/282 [==============================] - 4s 16ms/step - loss: 7.0886e-05 - val_loss: 8.6847e-04
# Epoch 17/50
# 282/282 [==============================] - 4s 16ms/step - loss: 7.3467e-05 - val_loss: 9.2553e-04
# Epoch 18/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.6533e-05 - val_loss: 9.5951e-04
# Epoch 19/50
# 282/282 [==============================] - 4s 16ms/step - loss: 7.9383e-05 - val_loss: 9.6086e-04
# Epoch 20/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.1921e-05 - val_loss: 9.2614e-04
# Epoch 21/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.4442e-05 - val_loss: 8.7378e-04
# Epoch 22/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.7789e-05 - val_loss: 8.1521e-04
# Epoch 23/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.1686e-05 - val_loss: 7.5722e-04
# Epoch 24/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.5257e-05 - val_loss: 7.0553e-04
# Epoch 25/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.7820e-05 - val_loss: 6.6056e-04
# Epoch 26/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.9296e-05 - val_loss: 6.2023e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 16ms/step - loss: 1.0003e-04 - val_loss: 5.8273e-04
# Epoch 28/50
# 282/282 [==============================] - 4s 16ms/step - loss: 1.0033e-04 - val_loss: 5.4740e-04
# Epoch 29/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0035e-04 - val_loss: 5.1443e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 16ms/step - loss: 1.0012e-04 - val_loss: 4.8448e-04
# Epoch 31/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.9600e-05 - val_loss: 4.5851e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.8730e-05 - val_loss: 4.3779e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.7487e-05 - val_loss: 4.2341e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.5938e-05 - val_loss: 4.1528e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.4246e-05 - val_loss: 4.1193e-04
# Epoch 36/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.2514e-05 - val_loss: 4.1196e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.0893e-05 - val_loss: 4.1394e-04
# Epoch 38/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.9573e-05 - val_loss: 4.1809e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.8059e-05 - val_loss: 4.1804e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.7103e-05 - val_loss: 4.2241e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.5995e-05 - val_loss: 4.2497e-04
# Epoch 42/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.5768e-05 - val_loss: 4.1936e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.8316e-05 - val_loss: 4.3315e-04
# Epoch 44/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.6854e-05 - val_loss: 4.2386e-04
# Epoch 45/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.9676e-05 - val_loss: 4.4358e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.7753e-05 - val_loss: 4.5877e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.3972e-05 - val_loss: 4.4588e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.2003e-05 - val_loss: 4.4408e-04
# Epoch 49/50
# 282/282 [==============================] - 4s 16ms/step - loss: 7.9622e-05 - val_loss: 4.1202e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.3386e-05 - val_loss: 4.0856e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 7ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.5389486 ]
#  [0.54844284]
#  [0.521403  ]
#  [0.5752911 ]
#  [0.59193474]
#  [0.59446025]
#  [0.56305766]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 8ms/step - loss: 2.7910e-04
# 0.0002791037259157747

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0856e-04
# 0.0004085644904989749

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0141

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0202

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.538949
# 1       0.524931  0.548443
# 2       0.577541  0.521403
# 3       0.594170  0.575291
# 4       0.596957  0.591935
# ..           ...       ...
# 515     0.272496  0.301842
# 516     0.233016  0.273117
# 517     0.258332  0.237964
# 518     0.250134  0.262120
# 519     0.245951  0.250983
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 6s 12ms/step - loss: 7.9505e-04 - val_loss: 0.0245
# Epoch 2/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0030 - val_loss: 0.0245
# Epoch 3/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0021 - val_loss: 0.0197
# Epoch 4/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0018 - val_loss: 0.0209
# Epoch 5/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0015 - val_loss: 0.0156
# Epoch 6/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0010 - val_loss: 0.0115
# Epoch 7/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.2300e-04 - val_loss: 0.0083
# Epoch 8/50
# 282/282 [==============================] - 3s 9ms/step - loss: 4.0243e-04 - val_loss: 0.0035
# Epoch 9/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.7567e-04 - val_loss: 0.0021
# Epoch 10/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1665e-04 - val_loss: 0.0017
# Epoch 11/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.0258e-04 - val_loss: 0.0015
# Epoch 12/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.6571e-05 - val_loss: 0.0014
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.1597e-05 - val_loss: 0.0013
# Epoch 14/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.5693e-05 - val_loss: 0.0013
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9039e-05 - val_loss: 0.0013
# Epoch 16/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.3111e-05 - val_loss: 0.0013
# Epoch 17/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9381e-05 - val_loss: 0.0014
# Epoch 18/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.8253e-05 - val_loss: 0.0015
# Epoch 19/50
# 282/282 [==============================] - 3s 9ms/step - loss: 6.9075e-05 - val_loss: 0.0016
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.0853e-05 - val_loss: 0.0018
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2919e-05 - val_loss: 0.0019
# Epoch 22/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.4763e-05 - val_loss: 0.0019
# Epoch 23/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6020e-05 - val_loss: 0.0019
# Epoch 24/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6752e-05 - val_loss: 0.0019
# Epoch 25/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7288e-05 - val_loss: 0.0019
# Epoch 26/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7925e-05 - val_loss: 0.0018
# Epoch 27/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8805e-05 - val_loss: 0.0018
# Epoch 28/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9932e-05 - val_loss: 0.0017
# Epoch 29/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1207e-05 - val_loss: 0.0017
# Epoch 30/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.2478e-05 - val_loss: 0.0016
# Epoch 31/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.3655e-05 - val_loss: 0.0016
# Epoch 32/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.4328e-05 - val_loss: 0.0016
# Epoch 33/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.4490e-05 - val_loss: 0.0015
# Epoch 34/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.3979e-05 - val_loss: 0.0015
# Epoch 35/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.2986e-05 - val_loss: 0.0014
# Epoch 36/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1900e-05 - val_loss: 0.0014
# Epoch 37/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.1165e-05 - val_loss: 0.0013
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0211e-05 - val_loss: 0.0013
# Epoch 39/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9441e-05 - val_loss: 0.0013
# Epoch 40/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8970e-05 - val_loss: 0.0013
# Epoch 41/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.8986e-05 - val_loss: 0.0013
# Epoch 42/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9782e-05 - val_loss: 0.0013
# Epoch 43/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9217e-05 - val_loss: 0.0013
# Epoch 44/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8959e-05 - val_loss: 0.0013
# Epoch 45/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8498e-05 - val_loss: 0.0013
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7736e-05 - val_loss: 0.0013
# Epoch 47/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7426e-05 - val_loss: 0.0013
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7357e-05 - val_loss: 0.0013
# Epoch 49/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6857e-05 - val_loss: 0.0013
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6856e-05 - val_loss: 0.0013

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 6ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.58704025]
#  [0.5970232 ]
#  [0.57025075]
#  [0.62212116]
#  [0.63641423]
#  [0.63688415]
#  [0.6041087 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.4647e-04
# 0.0007464682566933334

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013
# 0.0013311130460351706

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0320

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0013

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0365

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.587040
# 1       0.524931  0.597023
# 2       0.577541  0.570251
# 3       0.594170  0.622121
# 4       0.596957  0.636414
# ..           ...       ...
# 515     0.272496  0.333763
# 516     0.233016  0.304024
# 517     0.258332  0.265556
# 518     0.250134  0.290334
# 519     0.245951  0.282557
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9937 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 12s 22ms/step - loss: 6.4215e-04 - val_loss: 0.0160
# Epoch 2/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0022 - val_loss: 0.0298
# Epoch 3/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 4/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 5/50
# 282/282 [==============================] - 5s 19ms/step - loss: 3.2284e-04 - val_loss: 5.8150e-04
# Epoch 6/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.2467e-05 - val_loss: 5.1167e-04
# Epoch 7/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.2276e-05 - val_loss: 4.3833e-04
# Epoch 8/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.5013e-05 - val_loss: 4.7720e-04
# Epoch 9/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.9628e-05 - val_loss: 6.9362e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.8434e-05 - val_loss: 0.0012
# Epoch 11/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1204e-04 - val_loss: 0.0019
# Epoch 12/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3372e-04 - val_loss: 0.0024
# Epoch 13/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4694e-04 - val_loss: 0.0026
# Epoch 14/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5115e-04 - val_loss: 0.0027
# Epoch 15/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5336e-04 - val_loss: 0.0027
# Epoch 16/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5369e-04 - val_loss: 0.0027
# Epoch 17/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5358e-04 - val_loss: 0.0027
# Epoch 18/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5148e-04 - val_loss: 0.0027
# Epoch 19/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5147e-04 - val_loss: 0.0026
# Epoch 20/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4832e-04 - val_loss: 0.0022
# Epoch 21/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4878e-04 - val_loss: 0.0019
# Epoch 22/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5061e-04 - val_loss: 0.0017
# Epoch 23/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5327e-04 - val_loss: 0.0014
# Epoch 24/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5680e-04 - val_loss: 0.0012
# Epoch 25/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.5699e-04 - val_loss: 0.0010
# Epoch 26/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5475e-04 - val_loss: 9.8916e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.4877e-04 - val_loss: 0.0011
# Epoch 28/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3931e-04 - val_loss: 0.0010
# Epoch 29/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3333e-04 - val_loss: 0.0010
# Epoch 30/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3319e-04 - val_loss: 0.0011
# Epoch 31/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3729e-04 - val_loss: 9.6771e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4039e-04 - val_loss: 8.6728e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4279e-04 - val_loss: 7.4204e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4393e-04 - val_loss: 6.9224e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4491e-04 - val_loss: 6.7710e-04
# Epoch 36/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3963e-04 - val_loss: 6.8398e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3440e-04 - val_loss: 6.9620e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3131e-04 - val_loss: 7.1927e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2823e-04 - val_loss: 7.2432e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2481e-04 - val_loss: 7.1846e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2208e-04 - val_loss: 6.9225e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2442e-04 - val_loss: 6.5826e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2831e-04 - val_loss: 6.3384e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3031e-04 - val_loss: 6.1781e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2958e-04 - val_loss: 6.1506e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2711e-04 - val_loss: 6.0030e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2563e-04 - val_loss: 6.0350e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2559e-04 - val_loss: 5.9129e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2296e-04 - val_loss: 5.8682e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2121e-04 - val_loss: 5.8242e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 9ms/step
# [[0.56036747]
#  [0.5688781 ]
#  [0.54127663]
#  [0.5923611 ]
#  [0.6089108 ]
#  [0.6096637 ]
#  [0.5757743 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 9ms/step - loss: 7.7281e-04
# 0.0007728129276074469

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 5.8242e-04
# 0.0005824213731102645

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0177

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0006

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0241

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.560367
# 1       0.524931  0.568878
# 2       0.577541  0.541277
# 3       0.594170  0.592361
# 4       0.596957  0.608911
# ..           ...       ...
# 515     0.272496  0.292036
# 516     0.233016  0.264347
# 517     0.258332  0.229972
# 518     0.250134  0.256236
# 519     0.245951  0.246461
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9931 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.023054  0.000762  0.027610
# 1  Percobaan 2  0.014117  0.000409  0.020213
# 2  Percobaan 3  0.031958  0.001331  0.036484
# 3  Percobaan 4  0.017702  0.000582  0.024133

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.25)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:12:57.26
