# %% [markdown]
# # Prediction of BTC-USD Price with algorithm LSTM-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(1234)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling LSTM-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla LSTM-RNN

# %%
tf.random.set_seed(1234)

# %%
# The LSTM-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.LSTM(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model LSTM
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 5s 11ms/step - loss: 5.3706e-04 - val_loss: 0.0177
# Epoch 2/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0018 - val_loss: 0.0045
# Epoch 3/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 4/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.6942e-04 - val_loss: 0.0041
# Epoch 5/50
# 282/282 [==============================] - 3s 10ms/step - loss: 4.5978e-04 - val_loss: 0.0048
# Epoch 6/50
# 282/282 [==============================] - 3s 9ms/step - loss: 3.1802e-04 - val_loss: 0.0049
# Epoch 7/50
# 282/282 [==============================] - 3s 9ms/step - loss: 2.2725e-04 - val_loss: 0.0044
# Epoch 8/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.6919e-04 - val_loss: 0.0040
# Epoch 9/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.4948e-04 - val_loss: 0.0039
# Epoch 10/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.4303e-04 - val_loss: 0.0038
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3926e-04 - val_loss: 0.0038
# Epoch 12/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3662e-04 - val_loss: 0.0039
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3466e-04 - val_loss: 0.0040
# Epoch 14/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3303e-04 - val_loss: 0.0041
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3149e-04 - val_loss: 0.0042
# Epoch 16/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.3001e-04 - val_loss: 0.0042
# Epoch 17/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2861e-04 - val_loss: 0.0043
# Epoch 18/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2730e-04 - val_loss: 0.0043
# Epoch 19/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2602e-04 - val_loss: 0.0044
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2478e-04 - val_loss: 0.0044
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2368e-04 - val_loss: 0.0045
# Epoch 22/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2290e-04 - val_loss: 0.0046
# Epoch 23/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2180e-04 - val_loss: 0.0047
# Epoch 24/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2181e-04 - val_loss: 0.0046
# Epoch 25/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1306e-04 - val_loss: 0.0049
# Epoch 26/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1807e-04 - val_loss: 0.0049
# Epoch 27/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1681e-04 - val_loss: 0.0051
# Epoch 28/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1626e-04 - val_loss: 0.0052
# Epoch 29/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2119e-04 - val_loss: 0.0053
# Epoch 30/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2273e-04 - val_loss: 0.0055
# Epoch 31/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2226e-04 - val_loss: 0.0059
# Epoch 32/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2041e-04 - val_loss: 0.0063
# Epoch 33/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3230e-04 - val_loss: 0.0060
# Epoch 34/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2135e-04 - val_loss: 0.0071
# Epoch 35/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3880e-04 - val_loss: 0.0066
# Epoch 36/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3863e-04 - val_loss: 0.0072
# Epoch 37/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.4074e-04 - val_loss: 0.0079
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.4744e-04 - val_loss: 0.0081
# Epoch 39/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.6012e-04 - val_loss: 0.0066
# Epoch 40/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3872e-04 - val_loss: 0.0072
# Epoch 41/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.6940e-04 - val_loss: 0.0059
# Epoch 42/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2303e-04 - val_loss: 0.0050
# Epoch 43/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.5772e-04 - val_loss: 0.0036
# Epoch 44/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2448e-04 - val_loss: 0.0025
# Epoch 45/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.0832e-04 - val_loss: 0.0017
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.1853e-05 - val_loss: 0.0013
# Epoch 47/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1326e-05 - val_loss: 0.0012
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6232e-05 - val_loss: 0.0012
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3855e-05 - val_loss: 0.0012
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2972e-05 - val_loss: 0.0013

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10400
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.5856577 ]
#  [0.5902624 ]
#  [0.56618226]
#  [0.6090213 ]
#  [0.6339557 ]
#  [0.63761604]
#  [0.6075789 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla LSTM-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 1.6464e-04
# 0.00016464329382870346

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0013
# 0.00131896510720253

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0317

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0013

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0363

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.585658
# 1       0.524931  0.590262
# 2       0.577541  0.566182
# 3       0.594170  0.609021
# 4       0.596957  0.633956
# ..           ...       ...
# 515     0.272496  0.329765
# 516     0.233016  0.302795
# 517     0.258332  0.263540
# 518     0.250134  0.276224
# 519     0.245951  0.275425
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9930 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla LSTM-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla LSTM-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla LSTM-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked LSTM-RNN

# %%
tf.random.set_seed(1234)

# %%
# The LSTM-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First LSTM layer with Dropout regularisation
    tf.keras.layers.LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound LSTM layer with Dropout regularisation
    tf.keras.layers.LSTM(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model LSTM
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 9s 22ms/step - loss: 0.0013 - val_loss: 0.0179
# Epoch 2/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0040 - val_loss: 0.0309
# Epoch 3/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0060 - val_loss: 0.0279
# Epoch 4/50
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0050 - val_loss: 0.0698
# Epoch 5/50
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0025 - val_loss: 0.0500
# Epoch 6/50
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0012 - val_loss: 0.0130
# Epoch 7/50
# 282/282 [==============================] - 6s 20ms/step - loss: 3.8914e-04 - val_loss: 0.0063
# Epoch 8/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.5301e-04 - val_loss: 0.0047
# Epoch 9/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.0568e-04 - val_loss: 0.0042
# Epoch 10/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.8482e-04 - val_loss: 0.0041
# Epoch 11/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.7719e-04 - val_loss: 0.0042
# Epoch 12/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.7499e-04 - val_loss: 0.0045
# Epoch 13/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.7556e-04 - val_loss: 0.0049
# Epoch 14/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.7837e-04 - val_loss: 0.0055
# Epoch 15/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.8329e-04 - val_loss: 0.0061
# Epoch 16/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.9033e-04 - val_loss: 0.0068
# Epoch 17/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.9901e-04 - val_loss: 0.0075
# Epoch 18/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.0871e-04 - val_loss: 0.0082
# Epoch 19/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.1941e-04 - val_loss: 0.0089
# Epoch 20/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.3077e-04 - val_loss: 0.0096
# Epoch 21/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.4229e-04 - val_loss: 0.0103
# Epoch 22/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.5413e-04 - val_loss: 0.0112
# Epoch 23/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.6771e-04 - val_loss: 0.0124
# Epoch 24/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.8477e-04 - val_loss: 0.0144
# Epoch 25/50
# 282/282 [==============================] - 5s 19ms/step - loss: 2.8443e-04 - val_loss: 0.0174
# Epoch 26/50
# 282/282 [==============================] - 5s 18ms/step - loss: 3.2382e-04 - val_loss: 0.0189
# Epoch 27/50
# 282/282 [==============================] - 5s 18ms/step - loss: 3.5187e-04 - val_loss: 0.0214
# Epoch 28/50
# 282/282 [==============================] - 5s 19ms/step - loss: 4.1400e-04 - val_loss: 0.0190
# Epoch 29/50
# 282/282 [==============================] - 5s 19ms/step - loss: 3.7162e-04 - val_loss: 0.0277
# Epoch 30/50
# 282/282 [==============================] - 5s 18ms/step - loss: 4.9091e-04 - val_loss: 0.0271
# Epoch 31/50
# 282/282 [==============================] - 5s 19ms/step - loss: 4.4467e-04 - val_loss: 0.0242
# Epoch 32/50
# 282/282 [==============================] - 5s 18ms/step - loss: 4.2992e-04 - val_loss: 0.0198
# Epoch 33/50
# 282/282 [==============================] - 5s 18ms/step - loss: 3.0893e-04 - val_loss: 0.0077
# Epoch 34/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.7466e-04 - val_loss: 0.0020
# Epoch 35/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.1869e-05 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.6533e-05 - val_loss: 9.4896e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.5219e-05 - val_loss: 6.1818e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.4280e-05 - val_loss: 7.1964e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0162e-04 - val_loss: 5.2245e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.6215e-05 - val_loss: 5.9818e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0342e-04 - val_loss: 5.3435e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0189e-04 - val_loss: 4.9725e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0489e-04 - val_loss: 4.8947e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1050e-04 - val_loss: 4.6783e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0960e-04 - val_loss: 4.9537e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0974e-04 - val_loss: 6.6936e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.2041e-05 - val_loss: 5.0740e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.2213e-04 - val_loss: 5.1154e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.3700e-04 - val_loss: 5.8406e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3506e-04 - val_loss: 6.5628e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60, 50)            10400
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 9ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.56019604]
#  [0.5714855 ]
#  [0.5428498 ]
#  [0.5937578 ]
#  [0.6091192 ]
#  [0.61462647]
#  [0.58221   ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked LSTM-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 10ms/step - loss: 0.0018
# 0.00184429413639009

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 6.5628e-04
# 0.000656277930829674

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0203

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0007

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0256

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.560196
# 1       0.524931  0.571486
# 2       0.577541  0.542850
# 3       0.594170  0.593758
# 4       0.596957  0.609119
# ..           ...       ...
# 515     0.272496  0.319659
# 516     0.233016  0.291478
# 517     0.258332  0.254078
# 518     0.250134  0.272401
# 519     0.245951  0.267001
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9936 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked LSTM-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked LSTM-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked LSTM-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional LSTM-RNN

# %%
tf.random.set_seed(1234)

# %%
# The LSTM-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model LSTM
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 7s 13ms/step - loss: 8.8779e-04 - val_loss: 0.0480
# Epoch 2/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0038 - val_loss: 0.0141
# Epoch 3/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0027 - val_loss: 0.0239
# Epoch 4/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0017 - val_loss: 0.0285
# Epoch 5/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0011 - val_loss: 0.0236
# Epoch 6/50
# 282/282 [==============================] - 3s 11ms/step - loss: 5.8374e-04 - val_loss: 0.0135
# Epoch 7/50
# 282/282 [==============================] - 3s 11ms/step - loss: 2.6625e-04 - val_loss: 0.0104
# Epoch 8/50
# 282/282 [==============================] - 3s 11ms/step - loss: 2.0433e-04 - val_loss: 0.0102
# Epoch 9/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.9564e-04 - val_loss: 0.0105
# Epoch 10/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.9212e-04 - val_loss: 0.0110
# Epoch 11/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8926e-04 - val_loss: 0.0115
# Epoch 12/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8639e-04 - val_loss: 0.0120
# Epoch 13/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.8370e-04 - val_loss: 0.0125
# Epoch 14/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8157e-04 - val_loss: 0.0130
# Epoch 15/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8008e-04 - val_loss: 0.0134
# Epoch 16/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.7885e-04 - val_loss: 0.0137
# Epoch 17/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.7641e-04 - val_loss: 0.0139
# Epoch 18/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.7433e-04 - val_loss: 0.0140
# Epoch 19/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.7950e-04 - val_loss: 0.0138
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.7996e-04 - val_loss: 0.0137
# Epoch 21/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8681e-04 - val_loss: 0.0140
# Epoch 22/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8886e-04 - val_loss: 0.0122
# Epoch 23/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.9377e-04 - val_loss: 0.0109
# Epoch 24/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.9097e-04 - val_loss: 0.0076
# Epoch 25/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.8371e-04 - val_loss: 0.0063
# Epoch 26/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.6222e-04 - val_loss: 0.0056
# Epoch 27/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.5507e-04 - val_loss: 0.0051
# Epoch 28/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.4429e-04 - val_loss: 0.0046
# Epoch 29/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.3798e-04 - val_loss: 0.0042
# Epoch 30/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.2933e-04 - val_loss: 0.0038
# Epoch 31/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.2450e-04 - val_loss: 0.0035
# Epoch 32/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.1855e-04 - val_loss: 0.0032
# Epoch 33/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.1319e-04 - val_loss: 0.0030
# Epoch 34/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.0915e-04 - val_loss: 0.0028
# Epoch 35/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.0549e-04 - val_loss: 0.0026
# Epoch 36/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.0226e-04 - val_loss: 0.0025
# Epoch 37/50
# 282/282 [==============================] - 3s 11ms/step - loss: 9.8825e-05 - val_loss: 0.0024
# Epoch 38/50
# 282/282 [==============================] - 3s 11ms/step - loss: 9.6290e-05 - val_loss: 0.0024
# Epoch 39/50
# 282/282 [==============================] - 3s 12ms/step - loss: 9.3259e-05 - val_loss: 0.0023
# Epoch 40/50
# 282/282 [==============================] - 3s 11ms/step - loss: 9.2734e-05 - val_loss: 0.0023
# Epoch 41/50
# 282/282 [==============================] - 3s 11ms/step - loss: 9.0191e-05 - val_loss: 0.0022
# Epoch 42/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.7717e-05 - val_loss: 0.0021
# Epoch 43/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.6472e-05 - val_loss: 0.0021
# Epoch 44/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.5680e-05 - val_loss: 0.0020
# Epoch 45/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.4467e-05 - val_loss: 0.0020
# Epoch 46/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.4018e-05 - val_loss: 0.0019
# Epoch 47/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2968e-05 - val_loss: 0.0019
# Epoch 48/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.2371e-05 - val_loss: 0.0019
# Epoch 49/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.1570e-05 - val_loss: 0.0018
# Epoch 50/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.0757e-05 - val_loss: 0.0018

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 20800
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 20,901
# Trainable params: 20,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 7ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.6063658 ]
#  [0.6148196 ]
#  [0.589953  ]
#  [0.63739675]
#  [0.6557897 ]
#  [0.65605444]
#  [0.6228902 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional LSTM-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 6ms/step - loss: 2.2915e-04
# 0.00022914769942872226

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0018
# 0.0017753448337316513

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0367

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0018

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0421

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.606366
# 1       0.524931  0.614820
# 2       0.577541  0.589953
# 3       0.594170  0.637397
# 4       0.596957  0.655790
# ..           ...       ...
# 515     0.272496  0.329414
# 516     0.233016  0.302708
# 517     0.258332  0.265677
# 518     0.250134  0.282795
# 519     0.245951  0.276319
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9920 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional LSTM-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional LSTM-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional LSTM-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional LSTM-RNN

# %%
tf.random.set_seed(1234)

# %%
# The LSTM-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First LSTM layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound LSTM layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model LSTM
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 14s 28ms/step - loss: 9.1893e-04 - val_loss: 0.0204
# Epoch 2/50
# 282/282 [==============================] - 7s 24ms/step - loss: 0.0029 - val_loss: 0.0298
# Epoch 3/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0039 - val_loss: 0.0167
# Epoch 4/50
# 282/282 [==============================] - 6s 23ms/step - loss: 0.0023 - val_loss: 0.0185
# Epoch 5/50
# 282/282 [==============================] - 6s 23ms/step - loss: 0.0011 - val_loss: 0.0261
# Epoch 6/50
# 282/282 [==============================] - 6s 21ms/step - loss: 4.7812e-04 - val_loss: 0.0222
# Epoch 7/50
# 282/282 [==============================] - 6s 21ms/step - loss: 4.8117e-04 - val_loss: 0.0145
# Epoch 8/50
# 282/282 [==============================] - 6s 22ms/step - loss: 2.1954e-04 - val_loss: 0.0134
# Epoch 9/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.9402e-04 - val_loss: 0.0127
# Epoch 10/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.7774e-04 - val_loss: 0.0127
# Epoch 11/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.7726e-04 - val_loss: 0.0128
# Epoch 12/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.8909e-04 - val_loss: 0.0128
# Epoch 13/50
# 282/282 [==============================] - 6s 22ms/step - loss: 2.1857e-04 - val_loss: 0.0122
# Epoch 14/50
# 282/282 [==============================] - 6s 21ms/step - loss: 2.2386e-04 - val_loss: 0.0109
# Epoch 15/50
# 282/282 [==============================] - 6s 21ms/step - loss: 2.2345e-04 - val_loss: 0.0096
# Epoch 16/50
# 282/282 [==============================] - 6s 21ms/step - loss: 2.1623e-04 - val_loss: 0.0081
# Epoch 17/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.9570e-04 - val_loss: 0.0071
# Epoch 18/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.8712e-04 - val_loss: 0.0060
# Epoch 19/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.6896e-04 - val_loss: 0.0053
# Epoch 20/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.5654e-04 - val_loss: 0.0044
# Epoch 21/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.4302e-04 - val_loss: 0.0037
# Epoch 22/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3394e-04 - val_loss: 0.0031
# Epoch 23/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.2703e-04 - val_loss: 0.0027
# Epoch 24/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2291e-04 - val_loss: 0.0023
# Epoch 25/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2130e-04 - val_loss: 0.0021
# Epoch 26/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2184e-04 - val_loss: 0.0019
# Epoch 27/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2306e-04 - val_loss: 0.0017
# Epoch 28/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2238e-04 - val_loss: 0.0015
# Epoch 29/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1987e-04 - val_loss: 0.0014
# Epoch 30/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1898e-04 - val_loss: 0.0012
# Epoch 31/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2005e-04 - val_loss: 0.0011
# Epoch 32/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2104e-04 - val_loss: 9.5539e-04
# Epoch 33/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2154e-04 - val_loss: 9.7374e-04
# Epoch 34/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2754e-04 - val_loss: 0.0012
# Epoch 35/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2501e-04 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1369e-04 - val_loss: 7.2468e-04
# Epoch 37/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.0105e-04 - val_loss: 7.5083e-04
# Epoch 38/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.2344e-04 - val_loss: 7.0582e-04
# Epoch 39/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.5767e-04 - val_loss: 5.2913e-04
# Epoch 40/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.8858e-04 - val_loss: 5.7189e-04
# Epoch 41/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.9755e-04 - val_loss: 5.6100e-04
# Epoch 42/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.8388e-04 - val_loss: 5.3168e-04
# Epoch 43/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.4216e-04 - val_loss: 4.9571e-04
# Epoch 44/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.0883e-04 - val_loss: 4.3535e-04
# Epoch 45/50
# 282/282 [==============================] - 6s 23ms/step - loss: 9.5632e-05 - val_loss: 4.2170e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 21ms/step - loss: 9.3515e-05 - val_loss: 4.5425e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.8963e-05 - val_loss: 4.7728e-04
# Epoch 48/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.6117e-05 - val_loss: 4.8251e-04
# Epoch 49/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.6023e-05 - val_loss: 4.8627e-04
# Epoch 50/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.7932e-05 - val_loss: 4.9270e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             20800
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 60400
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 81,301
# Trainable params: 81,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 12ms/step
# [[0.56255525]
#  [0.5718925 ]
#  [0.5443713 ]
#  [0.5963315 ]
#  [0.6136093 ]
#  [0.6140983 ]
#  [0.5785726 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional LSTM-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 12ms/step - loss: 3.3230e-04
# 0.0003323045966681093

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 11ms/step - loss: 4.9270e-04
# 0.0004926962428726256

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0161

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0005

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0222

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.562555
# 1       0.524931  0.571892
# 2       0.577541  0.544371
# 3       0.594170  0.596331
# 4       0.596957  0.613609
# ..           ...       ...
# 515     0.272496  0.297965
# 516     0.233016  0.270134
# 517     0.258332  0.234060
# 518     0.250134  0.256484
# 519     0.245951  0.250164
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9937 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional LSTM-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.031702  0.001319  0.036318
# 1  Percobaan 2  0.020261  0.000656  0.025618
# 2  Percobaan 3  0.036727  0.001775  0.042135
# 3  Percobaan 4  0.016086  0.000493  0.022197

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla LSTM-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked LSTM-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional LSTM-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %%
##### membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla LSTM-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked LSTM-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional LSTM-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional LSTM-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:14:58.79
