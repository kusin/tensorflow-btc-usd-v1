# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 7s 15ms/step - loss: 8.1729e-04 - val_loss: 0.0118
# Epoch 2/50
# 282/282 [==============================] - 3s 12ms/step - loss: 0.0023 - val_loss: 0.0206
# Epoch 3/50
# 282/282 [==============================] - 3s 12ms/step - loss: 0.0016 - val_loss: 0.0104
# Epoch 4/50
# 282/282 [==============================] - 4s 13ms/step - loss: 6.7220e-04 - val_loss: 0.0026
# Epoch 5/50
# 282/282 [==============================] - 3s 12ms/step - loss: 2.1216e-04 - val_loss: 0.0012
# Epoch 6/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.2601e-04 - val_loss: 9.1856e-04
# Epoch 7/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.0895e-04 - val_loss: 8.6329e-04
# Epoch 8/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.0936e-04 - val_loss: 8.7110e-04
# Epoch 9/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.1433e-04 - val_loss: 8.9462e-04
# Epoch 10/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.1970e-04 - val_loss: 9.0933e-04
# Epoch 11/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.2224e-04 - val_loss: 8.9779e-04
# Epoch 12/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.1926e-04 - val_loss: 8.5151e-04
# Epoch 13/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.0994e-04 - val_loss: 7.7650e-04
# Epoch 14/50
# 282/282 [==============================] - 3s 12ms/step - loss: 9.6677e-05 - val_loss: 6.9383e-04
# Epoch 15/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.4389e-05 - val_loss: 6.3056e-04
# Epoch 16/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.6866e-05 - val_loss: 6.0638e-04
# Epoch 17/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.4462e-05 - val_loss: 6.1472e-04
# Epoch 18/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5135e-05 - val_loss: 6.3395e-04
# Epoch 19/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.6788e-05 - val_loss: 6.5268e-04
# Epoch 20/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.8473e-05 - val_loss: 6.6645e-04
# Epoch 21/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.9788e-05 - val_loss: 6.7364e-04
# Epoch 22/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0563e-05 - val_loss: 6.7447e-04
# Epoch 23/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0794e-05 - val_loss: 6.7024e-04
# Epoch 24/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.0577e-05 - val_loss: 6.6269e-04
# Epoch 25/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.0050e-05 - val_loss: 6.5346e-04
# Epoch 26/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9343e-05 - val_loss: 6.4391e-04
# Epoch 27/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.8548e-05 - val_loss: 6.3492e-04
# Epoch 28/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.7729e-05 - val_loss: 6.2753e-04
# Epoch 29/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.7129e-05 - val_loss: 6.2163e-04
# Epoch 30/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.6552e-05 - val_loss: 6.1698e-04
# Epoch 31/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5972e-05 - val_loss: 6.1340e-04
# Epoch 32/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5587e-05 - val_loss: 6.1209e-04
# Epoch 33/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5253e-05 - val_loss: 6.1213e-04
# Epoch 34/50
# 282/282 [==============================] - 4s 12ms/step - loss: 7.5006e-05 - val_loss: 6.1385e-04
# Epoch 35/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.4904e-05 - val_loss: 6.1648e-04
# Epoch 36/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.4834e-05 - val_loss: 6.2004e-04
# Epoch 37/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.4824e-05 - val_loss: 6.2478e-04
# Epoch 38/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.4875e-05 - val_loss: 6.3043e-04
# Epoch 39/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.4967e-05 - val_loss: 6.3652e-04
# Epoch 40/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5104e-05 - val_loss: 6.4280e-04
# Epoch 41/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5132e-05 - val_loss: 6.4948e-04
# Epoch 42/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5021e-05 - val_loss: 6.6005e-04
# Epoch 43/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5557e-05 - val_loss: 6.6728e-04
# Epoch 44/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5845e-05 - val_loss: 6.7216e-04
# Epoch 45/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5575e-05 - val_loss: 6.7725e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5824e-05 - val_loss: 6.8079e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5613e-05 - val_loss: 6.8246e-04
# Epoch 48/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5222e-05 - val_loss: 6.8739e-04
# Epoch 49/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5208e-05 - val_loss: 6.9155e-04
# Epoch 50/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.5001e-05 - val_loss: 6.9688e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 6ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.5601876 ]
#  [0.570865  ]
#  [0.54086185]
#  [0.594498  ]
#  [0.60975283]
#  [0.61485595]
#  [0.5811893 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 6ms/step - loss: 7.4165e-04
# 0.0007416516891680658

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 6ms/step - loss: 6.9688e-04
# 0.0006968756206333637

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0218

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0007

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0264

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.560188
# 1       0.524931  0.570865
# 2       0.577541  0.540862
# 3       0.594170  0.594498
# 4       0.596957  0.609753
# ..           ...       ...
# 515     0.272496  0.327203
# 516     0.233016  0.296953
# 517     0.258332  0.257635
# 518     0.250134  0.279928
# 519     0.245951  0.274014
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 11s 25ms/step - loss: 7.0803e-04 - val_loss: 0.0246
# Epoch 2/50
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0031 - val_loss: 0.0196
# Epoch 3/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0040 - val_loss: 0.0176
# Epoch 4/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0038 - val_loss: 0.0255
# Epoch 5/50
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0036 - val_loss: 0.0275
# Epoch 6/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.
50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.9860e-05 - val_loss: 4.9448e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.5797e-05 - val_loss: 5.0796e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.0889e-05 - val_loss: 4.7612e-04
# Epoch 48/50
# 282/282 [==============================] - 6s 21ms/step - loss: 7.9866e-05 - val_loss: 4.1858e-04
# Epoch 49/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.5533e-05 - val_loss: 4.0879e-04
# Epoch 50/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.9938e-05 - val_loss: 4.1902e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 10ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.53564906]
#  [0.54545724]
#  [0.51845336]
#  [0.5726188 ]
#  [0.5890176 ]
#  [0.5916171 ]
#  [0.5603393 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 2s 11ms/step - loss: 2.9662e-04
# 0.0002966156171169132

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 4.1902e-04
# 0.0004190234758425504

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0146

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0205

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.535649
# 1       0.524931  0.545457
# 2       0.577541  0.518453
# 3       0.594170  0.572619
# 4       0.596957  0.589018
# ..           ...       ...
# 515     0.272496  0.299045
# 516     0.233016  0.270229
# 517     0.258332  0.235362
# 518     0.250134  0.260308
# 519     0.245951  0.248361
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 9s 16ms/step - loss: 7.8877e-04 - val_loss: 0.0269
# Epoch 2/50
# 282/282 [==============================] - 3s 12ms/step - loss: 0.0031 - val_loss: 0.0382
# Epoch 3/50
# 282/282 [==============================] - 3s 12ms/step - loss: 0.0025 - val_loss: 0.0334
# Epoch 4/50
# 282/282 [==============================] - 4s 13ms/step - loss: 0.0021 - val_loss: 0.0306
# Epoch 5/50
50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5488e-05 - val_loss: 0.0016
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5372e-05 - val_loss: 0.0016
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5005e-05 - val_loss: 0.0016

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.59077066]
#  [0.6025483 ]
#  [0.5755745 ]
#  [0.6271563 ]
#  [0.6389682 ]
#  [0.6417078 ]
#  [0.6093342 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.6861e-04
# 0.0007686053868383169

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016
# 0.001592190470546484

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0353

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0016

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0399

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.590771
# 1       0.524931  0.602548
# 2       0.577541  0.575575
# 3       0.594170  0.627156
# 4       0.596957  0.638968
# ..           ...       ...
# 515     0.272496  0.337914
# 516     0.233016  0.308571
# 517     0.258332  0.270717
# 518     0.250134  0.294564
# 519     0.245951  0.285568
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9934 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 13s 24ms/step - loss: 7.5100e-04 - val_loss: 0.0191
# Epoch 2/50
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0025 - val_loss: 0.0211
# Epoch 3/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0034 - val_loss: 0.0063
# Epoch 4/50
# 282/282 [==============================] - 6s 20ms/step - loss: 0.0016 - val_loss: 0.0040
# Epoch 5/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 6/50
# 282/282 [==============================] - 6s 20ms/step - loss: 6.5959e-04 - val_loss: 0.0015
# Epoch 7/50
# 282/282 [==============================] - 6s 20ms/step - loss: 2.6847e-04 - val_loss: 8.3109e-04
# Epoch 8/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1926e-04 - val_loss: 6.2648e-04
# Epoch 9/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.6558e-05 - val_loss: 6.7965e-04
# Epoch 10/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.4818e-05 - val_loss: 8.2346e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.2780e-05 - val_loss: 0.0011
# Epoch 12/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.1471e-05 - val_loss: 0.0015
# Epoch 13/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.3871e-05 - val_loss: 0.0023
# Epoch 14/50
# 282/282 [==============================] - 6s 20ms/step - loss: 9.3642e-05 - val_loss: 0.0030
# Epoch 15/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1322e-04 - val_loss: 0.0030
# Epoch 16/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2669e-04 - val_loss: 0.0029
# Epoch 17/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2742e-04 - val_loss: 0.0028
# Epoch 18/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2745e-04 - val_loss: 0.0027
# Epoch 19/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2784e-04 - val_loss: 0.0027
# Epoch 20/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2766e-04 - val_loss: 0.0027
# Epoch 21/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2917e-04 - val_loss: 0.0029
# Epoch 22/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2716e-04 - val_loss: 0.0030
# Epoch 23/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2545e-04 - val_loss: 0.0024
# Epoch 24/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2371e-04 - val_loss: 0.0020
# Epoch 25/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2293e-04 - val_loss: 0.0019
# Epoch 26/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2458e-04 - val_loss: 0.0018
# Epoch 27/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2848e-04 - val_loss: 0.0016
# Epoch 28/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3338e-04 - val_loss: 0.0014
# Epoch 29/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3661e-04 - val_loss: 0.0012
# Epoch 30/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3661e-04 - val_loss: 0.0011
# Epoch 31/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3089e-04 - val_loss: 0.0012
# Epoch 32/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2274e-04 - val_loss: 0.0012
# Epoch 33/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1668e-04 - val_loss: 0.0012
# Epoch 34/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1725e-04 - val_loss: 0.0012
# Epoch 35/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2055e-04 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2670e-04 - val_loss: 9.4969e-04
# Epoch 37/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3320e-04 - val_loss: 7.7148e-04
# Epoch 38/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3815e-04 - val_loss: 6.3533e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3730e-04 - val_loss: 6.7356e-04
# Epoch 40/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2418e-04 - val_loss: 6.4395e-04
# Epoch 41/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2144e-04 - val_loss: 6.4282e-04
# Epoch 42/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2155e-04 - val_loss: 6.5259e-04
# Epoch 43/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1836e-04 - val_loss: 6.3559e-04
# Epoch 44/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1499e-04 - val_loss: 6.1567e-04
# Epoch 45/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1465e-04 - val_loss: 5.9957e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1774e-04 - val_loss: 5.7635e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2155e-04 - val_loss: 5.6225e-04
# Epoch 48/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2322e-04 - val_loss: 5.6613e-04
# Epoch 49/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1640e-04 - val_loss: 5.9398e-04
# Epoch 50/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1068e-04 - val_loss: 5.7939e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 9ms/step
# [[0.5661642 ]
#  [0.5775653 ]
#  [0.5493023 ]
#  [0.6015303 ]
#  [0.61594015]
#  [0.61746836]
#  [0.58302957]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 10ms/step - loss: 5.2600e-04
# 0.0005259956233203411

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 9ms/step - loss: 5.7939e-04
# 0.0005793924210593104

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0179

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0006

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0241

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.566164
# 1       0.524931  0.577565
# 2       0.577541  0.549302
# 3       0.594170  0.601530
# 4       0.596957  0.615940
# ..           ...       ...
# 515     0.272496  0.292506
# 516     0.233016  0.265543
# 517     0.258332  0.231273
# 518     0.250134  0.254766
# 519     0.245951  0.245140
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9931 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.021793  0.000697  0.026398
# 1  Percobaan 2  0.014597  0.000419  0.020470
# 2  Percobaan 3  0.035311  0.001592  0.039902
# 3  Percobaan 4  0.017921  0.000579  0.024071

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %%
##### membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:15:59.19
