# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("../dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 5s 10ms/step - loss: 4.1850e-04 - val_loss: 0.0070
# Epoch 2/50
# 282/282 [==============================] - 2s 8ms/step - loss: 0.0012 - val_loss: 0.0049
# Epoch 3/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.4327e-04 - val_loss: 0.0050
# Epoch 4/50
# 282/282 [==============================] - 2s 9ms/step - loss: 6.0458e-04 - val_loss: 0.0043
# Epoch 5/50
# 282/282 [==============================] - 2s 8ms/step - loss: 4.7508e-04 - val_loss: 0.0037
# Epoch 6/50
# 282/282 [==============================] - 2s 8ms/step - loss: 3.5218e-04 - val_loss: 0.0023
# Epoch 7/50
# 282/282 [==============================] - 2s 8ms/step - loss: 2.4448e-04 - val_loss: 0.0019
# Epoch 8/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.8802e-04 - val_loss: 0.0014
# Epoch 9/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.5027e-04 - val_loss: 0.0012
# Epoch 10/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2962e-04 - val_loss: 0.0011
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.1685e-04 - val_loss: 0.0010
# Epoch 12/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.0663e-04 - val_loss: 9.7103e-04
# Epoch 13/50
# 282/282 [==============================] - 2s 8ms/step - loss: 9.6615e-05 - val_loss: 9.0285e-04
# Epoch 14/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.6688e-05 - val_loss: 8.3436e-04
# Epoch 15/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.8331e-05 - val_loss: 7.7941e-04
# Epoch 16/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.3013e-05 - val_loss: 7.5315e-04
# Epoch 17/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.0855e-05 - val_loss: 7.5861e-04
# Epoch 18/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.0970e-05 - val_loss: 7.7956e-04
# Epoch 19/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.2090e-05 - val_loss: 7.9992e-04
# Epoch 20/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.3339e-05 - val_loss: 8.1351e-04
# Epoch 21/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.4368e-05 - val_loss: 8.1953e-04
# Epoch 22/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5087e-05 - val_loss: 8.1931e-04
# Epoch 23/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5511e-05 - val_loss: 8.1496e-04
# Epoch 24/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5707e-05 - val_loss: 8.0861e-04
# Epoch 25/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.5756e-05 - val_loss: 8.0193e-04
# Epoch 26/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5729e-05 - val_loss: 7.9599e-04
# Epoch 27/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5670e-05 - val_loss: 7.9133e-04
# Epoch 28/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5601e-05 - val_loss: 7.8806e-04
# Epoch 29/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5502e-05 - val_loss: 7.8573e-04
# Epoch 30/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.5333e-05 - val_loss: 7.8393e-04
# Epoch 31/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5197e-05 - val_loss: 7.8384e-04
# Epoch 32/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5119e-05 - val_loss: 7.8509e-04
# Epoch 33/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5114e-05 - val_loss: 7.8670e-04
# Epoch 34/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.5013e-05 - val_loss: 7.8837e-04
# Epoch 35/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.4829e-05 - val_loss: 7.9041e-04
# Epoch 36/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.4654e-05 - val_loss: 7.9351e-04
# Epoch 37/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.4465e-05 - val_loss: 8.0047e-04
# Epoch 38/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.4484e-05 - val_loss: 8.0640e-04
# Epoch 39/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.4362e-05 - val_loss: 8.1260e-04
# Epoch 40/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.4531e-05 - val_loss: 8.1064e-04
# Epoch 41/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.3832e-05 - val_loss: 8.1624e-04
# Epoch 42/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.3771e-05 - val_loss: 8.2125e-04
# Epoch 43/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.3720e-05 - val_loss: 8.2398e-04
# Epoch 44/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3429e-05 - val_loss: 8.2816e-04
# Epoch 45/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.3226e-05 - val_loss: 8.3187e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2875e-05 - val_loss: 8.3597e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.2657e-05 - val_loss: 8.4130e-04
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2412e-05 - val_loss: 8.4696e-04
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2182e-05 - val_loss: 8.5480e-04
# Epoch 50/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.2142e-05 - val_loss: 8.5893e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.56483096]
#  [0.5751379 ]
#  [0.54664916]
#  [0.6001332 ]
#  [0.6149829 ]
#  [0.61860275]
#  [0.5863614 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.0886e-04
# 0.0007088617421686649

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 8.5893e-04
# 0.0008589347708038986

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0249

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0009

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0293

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.564831
# 1       0.524931  0.575138
# 2       0.577541  0.546649
# 3       0.594170  0.600133
# 4       0.596957  0.614983
# ..           ...       ...
# 515     0.272496  0.331448
# 516     0.233016  0.301192
# 517     0.258332  0.261609
# 518     0.250134  0.284197
# 519     0.245951  0.278119
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9945 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 9s 21ms/step - loss: 6.6733e-04 - val_loss: 0.0202
# Epoch 2/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0029 - val_loss: 0.0211
# Epoch 3/50
# 282/282 [==============================] - 5s 16ms/step - loss: 0.0039 - val_loss: 0.0171
# Epoch 4/50
# 282/282 [==============================] - 4s 15ms/step - loss: 0.0034 - val_loss: 0.0168
# Epoch 5/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0033 - val_loss: 0.0174
# Epoch 6/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0031 - val_loss: 0.0272
# Epoch 7/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0025 - val_loss: 0.0244
# Epoch 8/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0013 - val_loss: 0.0084
# Epoch 9/50
# 282/282 [==============================] - 5s 17ms/step - loss: 3.7959e-04 - val_loss: 0.0021
# Epoch 10/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.0376e-05 - val_loss: 9.5921e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.5371e-05 - val_loss: 8.1191e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.2657e-05 - val_loss: 7.9008e-04
# Epoch 13/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.6657e-05 - val_loss: 8.2116e-04
# Epoch 14/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.4017e-05 - val_loss: 8.9175e-04
# Epoch 15/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.4897e-05 - val_loss: 9.8312e-04
# Epoch 16/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.7366e-05 - val_loss: 0.0011
# Epoch 17/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.9875e-05 - val_loss: 0.0011
# Epoch 18/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.2476e-05 - val_loss: 0.0012
# Epoch 19/50
# 282/282 [==============================] - 5s 17ms/step - loss: 7.5854e-05 - val_loss: 0.0012
# Epoch 20/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.9601e-05 - val_loss: 0.0012
# Epoch 21/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.3301e-05 - val_loss: 0.0012
# Epoch 22/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.6925e-05 - val_loss: 0.0011
# Epoch 23/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.0947e-05 - val_loss: 0.0011
# Epoch 24/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.4884e-05 - val_loss: 9.9807e-04
# Epoch 25/50
# 282/282 [==============================] - 6s 20ms/step - loss: 9.8191e-05 - val_loss: 9.2243e-04
# Epoch 26/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0060e-04 - val_loss: 8.4913e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0214e-04 - val_loss: 7.7707e-04
# Epoch 28/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.0299e-04 - val_loss: 7.0616e-04
# Epoch 29/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0332e-04 - val_loss: 6.3845e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0325e-04 - val_loss: 5.7643e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0281e-04 - val_loss: 5.2203e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0199e-04 - val_loss: 4.7716e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 16ms/step - loss: 1.0076e-04 - val_loss: 4.4401e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.9193e-05 - val_loss: 4.2358e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.7389e-05 - val_loss: 4.1392e-04
# Epoch 36/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.5472e-05 - val_loss: 4.1224e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.3624e-05 - val_loss: 4.1604e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.2130e-05 - val_loss: 4.2549e-04
# Epoch 39/50
# 282/282 [==============================] - 4s 15ms/step - loss: 9.0323e-05 - val_loss: 4.2995e-04
# Epoch 40/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.9773e-05 - val_loss: 4.3822e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.0296e-05 - val_loss: 4.4230e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.4181e-05 - val_loss: 4.6064e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.2008e-05 - val_loss: 4.6078e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 19ms/step - loss: 9.1667e-05 - val_loss: 5.1625e-04
# Epoch 45/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.4877e-05 - val_loss: 4.9226e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 20ms/step - loss: 8.1553e-05 - val_loss: 4.5262e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.2415e-05 - val_loss: 4.1306e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.7873e-05 - val_loss: 4.1269e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.0776e-05 - val_loss: 4.3101e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.7330e-05 - val_loss: 4.5522e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 8ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.53328556]
#  [0.54233   ]
#  [0.51499265]
#  [0.56926996]
#  [0.5865912 ]
#  [0.5891494 ]
#  [0.5572382 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 9ms/step - loss: 1.6557e-04
# 0.00016557071649003774

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 4.5522e-04
# 0.00045521752326749265

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0160

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0005

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0213

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.533286
# 1       0.524931  0.542330
# 2       0.577541  0.514993
# 3       0.594170  0.569270
# 4       0.596957  0.586591
# ..           ...       ...
# 515     0.272496  0.293848
# 516     0.233016  0.265098
# 517     0.258332  0.230076
# 518     0.250134  0.254508
# 519     0.245951  0.243073
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9945 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 7s 13ms/step - loss: 8.5237e-04 - val_loss: 0.0257
# Epoch 2/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0036 - val_loss: 0.0262
# Epoch 3/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0025 - val_loss: 0.0296
# Epoch 4/50
# 282/282 [==============================] - 4s 12ms/step - loss: 0.0022 - val_loss: 0.0308
# Epoch 5/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0135
# Epoch 6/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.4270e-04 - val_loss: 0.0086
# Epoch 7/50
# 282/282 [==============================] - 3s 11ms/step - loss: 4.0042e-04 - val_loss: 0.0028
# Epoch 8/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.4333e-04 - val_loss: 0.0019
# Epoch 9/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.1155e-04 - val_loss: 0.0016
# Epoch 10/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.0586e-04 - val_loss: 0.0015
# Epoch 11/50
# 282/282 [==============================] - 3s 12ms/step - loss: 1.0316e-04 - val_loss: 0.0014
# Epoch 12/50
# 282/282 [==============================] - 3s 12ms/step - loss: 9.9471e-05 - val_loss: 0.0013
# Epoch 13/50
# 282/282 [==============================] - 3s 11ms/step - loss: 9.3509e-05 - val_loss: 0.0012
# Epoch 14/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.5755e-05 - val_loss: 0.0012
# Epoch 15/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.8224e-05 - val_loss: 0.0012
# Epoch 16/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2964e-05 - val_loss: 0.0013
# Epoch 17/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.0811e-05 - val_loss: 0.0014
# Epoch 18/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.1208e-05 - val_loss: 0.0015
# Epoch 19/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.3066e-05 - val_loss: 0.0017
# Epoch 20/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5580e-05 - val_loss: 0.0018
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8118e-05 - val_loss: 0.0018
# Epoch 22/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0048e-05 - val_loss: 0.0018
# Epoch 23/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1130e-05 - val_loss: 0.0018
# Epoch 24/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1559e-05 - val_loss: 0.0017
# Epoch 25/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1667e-05 - val_loss: 0.0016
# Epoch 26/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1706e-05 - val_loss: 0.0016
# Epoch 27/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1800e-05 - val_loss: 0.0015
# Epoch 28/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1978e-05 - val_loss: 0.0014
# Epoch 29/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2215e-05 - val_loss: 0.0013
# Epoch 30/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2466e-05 - val_loss: 0.0013
# Epoch 31/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2687e-05 - val_loss: 0.0012
# Epoch 32/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2847e-05 - val_loss: 0.0012
# Epoch 33/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2926e-05 - val_loss: 0.0011
# Epoch 34/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2873e-05 - val_loss: 0.0011
# Epoch 35/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2520e-05 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2324e-05 - val_loss: 0.0010
# Epoch 37/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1844e-05 - val_loss: 0.0010
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1352e-05 - val_loss: 0.0010
# Epoch 39/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1207e-05 - val_loss: 9.8800e-04
# Epoch 40/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0865e-05 - val_loss: 9.8509e-04
# Epoch 41/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0809e-05 - val_loss: 9.7698e-04
# Epoch 42/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0846e-05 - val_loss: 9.6905e-04
# Epoch 43/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0283e-05 - val_loss: 9.7487e-04
# Epoch 44/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0553e-05 - val_loss: 9.7735e-04
# Epoch 45/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0457e-05 - val_loss: 9.8059e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0545e-05 - val_loss: 9.7480e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9896e-05 - val_loss: 9.8126e-04
# Epoch 48/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9925e-05 - val_loss: 9.8139e-04
# Epoch 49/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9583e-05 - val_loss: 9.8173e-04
# Epoch 50/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9359e-05 - val_loss: 9.6781e-04

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.5749508 ]
#  [0.58548015]
#  [0.55757576]
#  [0.61121184]
#  [0.6249667 ]
#  [0.6269056 ]
#  [0.5937096 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.5587e-04
# 0.0007558669312857091

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 6ms/step - loss: 9.6781e-04
# 0.0009678073693066835

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0267

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0010

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0311

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.574951
# 1       0.524931  0.585480
# 2       0.577541  0.557576
# 3       0.594170  0.611212
# 4       0.596957  0.624967
# ..           ...       ...
# 515     0.272496  0.328825
# 516     0.233016  0.298689
# 517     0.258332  0.260175
# 518     0.250134  0.285628
# 519     0.245951  0.277644
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9942 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 12s 25ms/step - loss: 7.5937e-04 - val_loss: 0.0259
# Epoch 2/50
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0028 - val_loss: 0.0207
# Epoch 3/50
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0034 - val_loss: 0.0071
# Epoch 4/50
# 282/282 [==============================] - 6s 21ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 5/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 6/50
# 282/282 [==============================] - 6s 23ms/step - loss: 6.4788e-04 - val_loss: 0.0014
# Epoch 7/50
# 282/282 [==============================] - 6s 21ms/step - loss: 2.7633e-04 - val_loss: 8.2248e-04
# Epoch 8/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1072e-04 - val_loss: 5.9733e-04
# Epoch 9/50
# 282/282 [==============================] - 6s 21ms/step - loss: 7.9465e-05 - val_loss: 5.2794e-04
# Epoch 10/50
# 282/282 [==============================] - 6s 21ms/step - loss: 8.0325e-05 - val_loss: 5.7495e-04
# Epoch 11/50
# 282/282 [==============================] - 6s 21ms/step - loss: 7.7501e-05 - val_loss: 7.8365e-04
# Epoch 12/50
# 282/282 [==============================] - 6s 22ms/step - loss: 7.8428e-05 - val_loss: 0.0012
# Epoch 13/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.4205e-05 - val_loss: 0.0019
# Epoch 14/50
# 282/282 [==============================] - 6s 21ms/step - loss: 9.6335e-05 - val_loss: 0.0026
# Epoch 15/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1695e-04 - val_loss: 0.0027
# Epoch 16/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2899e-04 - val_loss: 0.0027
# Epoch 17/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3178e-04 - val_loss: 0.0026
# Epoch 18/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3221e-04 - val_loss: 0.0026
# Epoch 19/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3217e-04 - val_loss: 0.0025
# Epoch 20/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3262e-04 - val_loss: 0.0026
# Epoch 21/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3255e-04 - val_loss: 0.0027
# Epoch 22/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.3113e-04 - val_loss: 0.0025
# Epoch 23/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.2999e-04 - val_loss: 0.0022
# Epoch 24/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2923e-04 - val_loss: 0.0019
# Epoch 25/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3118e-04 - val_loss: 0.0017
# Epoch 26/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.3356e-04 - val_loss: 0.0015
# Epoch 27/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.4038e-04 - val_loss: 0.0012
# Epoch 28/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.4824e-04 - val_loss: 9.8259e-04
# Epoch 29/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.5319e-04 - val_loss: 7.9199e-04
# Epoch 30/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.5166e-04 - val_loss: 6.5323e-04
# Epoch 31/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.4527e-04 - val_loss: 7.0461e-04
# Epoch 32/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2971e-04 - val_loss: 9.4254e-04
# Epoch 33/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1725e-04 - val_loss: 0.0010
# Epoch 34/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.1774e-04 - val_loss: 0.0012
# Epoch 35/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2102e-04 - val_loss: 0.0011
# Epoch 36/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2227e-04 - val_loss: 0.0010
# Epoch 37/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.2585e-04 - val_loss: 8.6329e-04
# Epoch 38/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.3928e-04 - val_loss: 6.8942e-04
# Epoch 39/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.5774e-04 - val_loss: 4.6014e-04
# Epoch 40/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.9090e-04 - val_loss: 4.9216e-04
# Epoch 41/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.7546e-04 - val_loss: 4.3811e-04
# Epoch 42/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.7963e-04 - val_loss: 4.2652e-04
# Epoch 43/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.6397e-04 - val_loss: 4.2495e-04
# Epoch 44/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.4215e-04 - val_loss: 5.0130e-04
# Epoch 45/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.1824e-04 - val_loss: 6.6762e-04
# Epoch 46/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.0551e-04 - val_loss: 7.5480e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.0287e-04 - val_loss: 7.4308e-04
# Epoch 48/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.0179e-04 - val_loss: 6.4098e-04
# Epoch 49/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.0537e-04 - val_loss: 5.1575e-04
# Epoch 50/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.2524e-04 - val_loss: 4.8993e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 9ms/step
# [[0.55832607]
#  [0.56880236]
#  [0.54070204]
#  [0.59351313]
#  [0.6086485 ]
#  [0.6106281 ]
#  [0.5778338 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 9ms/step - loss: 0.0021
# 0.002057404723018408

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 4.8993e-04
# 0.0004899334162473679

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0166

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0005

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0221

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.558326
# 1       0.524931  0.568802
# 2       0.577541  0.540702
# 3       0.594170  0.593513
# 4       0.596957  0.608648
# ..           ...       ...
# 515     0.272496  0.309563
# 516     0.233016  0.282209
# 517     0.258332  0.247570
# 518     0.250134  0.272710
# 519     0.245951  0.262916
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9942 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.024872  0.000859  0.029308
# 1  Percobaan 2  0.016038  0.000455  0.021336
# 2  Percobaan 3  0.026724  0.000968  0.031110
# 3  Percobaan 4  0.016553  0.000490  0.022134

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %%
##### membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:14:20.08
