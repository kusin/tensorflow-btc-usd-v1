# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 4s 11ms/step - loss: 6.8940e-04 - val_loss: 0.0105
# Epoch 2/50
# 282/282 [==============================] - 2s 9ms/step - loss: 0.0019 - val_loss: 0.0156
# Epoch 3/50
# 282/282 [==============================] - 2s 9ms/step - loss: 0.0013 - val_loss: 0.0100
# Epoch 4/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.5688e-04 - val_loss: 0.0053
# Epoch 5/50
# 282/282 [==============================] - 2s 9ms/step - loss: 3.9952e-04 - val_loss: 0.0025
# Epoch 6/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.9902e-04 - val_loss: 0.0013
# Epoch 7/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.2743e-04 - val_loss: 0.0011
# Epoch 8/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.0913e-04 - val_loss: 9.6098e-04
# Epoch 9/50
# 282/282 [==============================] - 2s 8ms/step - loss: 1.0393e-04 - val_loss: 9.3450e-04
# Epoch 10/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.0357e-04 - val_loss: 9.2683e-04
# Epoch 11/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.0358e-04 - val_loss: 9.1265e-04
# Epoch 12/50
# 282/282 [==============================] - 2s 9ms/step - loss: 1.0141e-04 - val_loss: 8.7978e-04
# Epoch 13/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.5945e-05 - val_loss: 8.2812e-04
# Epoch 14/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.8262e-05 - val_loss: 7.7001e-04
# Epoch 15/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.1111e-05 - val_loss: 7.2596e-04
# Epoch 16/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6781e-05 - val_loss: 7.1302e-04
# Epoch 17/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.5695e-05 - val_loss: 7.2419e-04
# Epoch 18/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6558e-05 - val_loss: 7.4174e-04
# Epoch 19/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7990e-05 - val_loss: 7.5651e-04
# Epoch 20/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9333e-05 - val_loss: 7.6527e-04
# Epoch 21/50
# 282/282 [==============================] - 2s 9ms/step - loss: 8.0317e-05 - val_loss: 7.6750e-04
# Epoch 22/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.0853e-05 - val_loss: 7.6418e-04
# Epoch 23/50
# 282/282 [==============================] - 2s 8ms/step - loss: 8.0968e-05 - val_loss: 7.5697e-04
# Epoch 24/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0752e-05 - val_loss: 7.4768e-04
# Epoch 25/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0313e-05 - val_loss: 7.3780e-04
# Epoch 26/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9737e-05 - val_loss: 7.2846e-04
# Epoch 27/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.9074e-05 - val_loss: 7.2068e-04
# Epoch 28/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8514e-05 - val_loss: 7.1501e-04
# Epoch 29/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.8031e-05 - val_loss: 7.1079e-04
# Epoch 30/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.7649e-05 - val_loss: 7.0900e-04
# Epoch 31/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7350e-05 - val_loss: 7.0923e-04
# Epoch 32/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7119e-05 - val_loss: 7.1106e-04
# Epoch 33/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7018e-05 - val_loss: 7.1387e-04
# Epoch 34/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.6863e-05 - val_loss: 7.1698e-04
# Epoch 35/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6704e-05 - val_loss: 7.2269e-04
# Epoch 36/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6946e-05 - val_loss: 7.2849e-04
# Epoch 37/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6665e-05 - val_loss: 7.3909e-04
# Epoch 38/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7041e-05 - val_loss: 7.4136e-04
# Epoch 39/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6871e-05 - val_loss: 7.4996e-04
# Epoch 40/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.7218e-05 - val_loss: 7.5189e-04
# Epoch 41/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6760e-05 - val_loss: 7.5799e-04
# Epoch 42/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.6947e-05 - val_loss: 7.5910e-04
# Epoch 43/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.6246e-05 - val_loss: 7.6488e-04
# Epoch 44/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.6351e-05 - val_loss: 7.6555e-04
# Epoch 45/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5800e-05 - val_loss: 7.7082e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6017e-05 - val_loss: 7.6842e-04
# Epoch 47/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.5121e-05 - val_loss: 7.7025e-04
# Epoch 48/50
# 282/282 [==============================] - 2s 8ms/step - loss: 7.4913e-05 - val_loss: 7.7640e-04
# Epoch 49/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.4820e-05 - val_loss: 7.7629e-04
# Epoch 50/50
# 282/282 [==============================] - 2s 9ms/step - loss: 7.4443e-05 - val_loss: 7.8093e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 0s 4ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.5630075 ]
#  [0.5731658 ]
#  [0.5437365 ]
#  [0.5974532 ]
#  [0.61287916]
#  [0.6168937 ]
#  [0.5836837 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 7.7532e-04
# 0.0007753220852464437

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 7.8093e-04
# 0.0007809259695932269

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0234

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0008

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0279

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.563007
# 1       0.524931  0.573166
# 2       0.577541  0.543737
# 3       0.594170  0.597453
# 4       0.596957  0.612879
# ..           ...       ...
# 515     0.272496  0.329708
# 516     0.233016  0.299214
# 517     0.258332  0.259538
# 518     0.250134  0.282303
# 519     0.245951  0.276501
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 8s 18ms/step - loss: 7.4631e-04 - val_loss: 0.0275
# Epoch 2/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0034 - val_loss: 0.0256
# Epoch 3/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0046 - val_loss: 0.0225
# Epoch 4/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0045 - val_loss: 0.0239
# Epoch 5/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0047 - val_loss: 0.0370
# Epoch 6/50
# 282/282 [==============================] - 5s 16ms/step - loss: 0.0048 - val_loss: 0.0625
# Epoch 7/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0033 - val_loss: 0.0222
# Epoch 8/50
# 282/282 [==============================] - 4s 16ms/step - loss: 0.0010 - val_loss: 8.7417e-04
# Epoch 9/50
# 282/282 [==============================] - 4s 16ms/step - loss: 1.1163e-04 - val_loss: 5.4997e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.4524e-05 - val_loss: 5.3156e-04
# Epoch 11/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.8766e-05 - val_loss: 5.4399e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.6894e-05 - val_loss: 5.6016e-04
# Epoch 13/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.6032e-05 - val_loss: 5.7871e-04
# Epoch 14/50
# 282/282 [==============================] - 5s 17ms/step - loss: 6.5853e-05 - val_loss: 6.0597e-04
# Epoch 15/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.6451e-05 - val_loss: 6.4671e-04
# Epoch 16/50
# 282/282 [==============================] - 4s 16ms/step - loss: 6.7876e-05 - val_loss: 6.9826e-04
# Epoch 17/50
# 282/282 [==============================] - 5s 16ms/step - loss: 6.9985e-05 - val_loss: 7.5019e-04
# Epoch 18/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.2524e-05 - val_loss: 8.0339e-04
# Epoch 19/50
# 282/282 [==============================] - 5s 16ms/step - loss: 7.5730e-05 - val_loss: 8.4135e-04
# Epoch 20/50
# 282/282 [==============================] - 4s 16ms/step - loss: 7.9092e-05 - val_loss: 8.4553e-04
# Epoch 21/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.2328e-05 - val_loss: 8.1126e-04
# Epoch 22/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.5743e-05 - val_loss: 7.4871e-04
# Epoch 23/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.9707e-05 - val_loss: 6.8337e-04
# Epoch 24/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.3931e-05 - val_loss: 6.2997e-04
# Epoch 25/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.7350e-05 - val_loss: 5.8827e-04
# Epoch 26/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.9615e-05 - val_loss: 5.5417e-04
# Epoch 27/50
# 282/282 [==============================] - 4s 16ms/step - loss: 1.0098e-04 - val_loss: 5.2422e-04
# Epoch 28/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0177e-04 - val_loss: 4.9693e-04
# Epoch 29/50
# 282/282 [==============================] - 4s 16ms/step - loss: 1.0218e-04 - val_loss: 4.7246e-04
# Epoch 30/50
# 282/282 [==============================] - 4s 16ms/step - loss: 1.0230e-04 - val_loss: 4.5174e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 17ms/step - loss: 1.0207e-04 - val_loss: 4.3606e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 16ms/step - loss: 1.0143e-04 - val_loss: 4.2665e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 16ms/step - loss: 1.0033e-04 - val_loss: 4.2406e-04
# Epoch 34/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.8790e-05 - val_loss: 4.2758e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.6953e-05 - val_loss: 4.3522e-04
# Epoch 36/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.5013e-05 - val_loss: 4.4458e-04
# Epoch 37/50
# 282/282 [==============================] - 4s 16ms/step - loss: 9.3165e-05 - val_loss: 4.5466e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 17ms/step - loss: 9.1462e-05 - val_loss: 4.6105e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.0076e-05 - val_loss: 4.6604e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.8897e-05 - val_loss: 4.6821e-04
# Epoch 41/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.8044e-05 - val_loss: 4.7285e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.7200e-05 - val_loss: 4.6508e-04
# Epoch 43/50
# 282/282 [==============================] - 4s 16ms/step - loss: 8.7621e-05 - val_loss: 4.6685e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.8419e-05 - val_loss: 4.4137e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.3231e-05 - val_loss: 4.6678e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.1513e-05 - val_loss: 4.9504e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 16ms/step - loss: 9.0195e-05 - val_loss: 5.7829e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.2111e-05 - val_loss: 5.3615e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 17ms/step - loss: 8.0768e-05 - val_loss: 4.5474e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 16ms/step - loss: 8.5352e-05 - val_loss: 4.1910e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 7ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.5355905 ]
#  [0.5452182 ]
#  [0.51772374]
#  [0.5721343 ]
#  [0.58811224]
#  [0.5905475 ]
#  [0.5588612 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 8ms/step - loss: 4.5429e-04
# 0.00045428957673721015

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 7ms/step - loss: 4.1910e-04
# 0.0004190972540527582

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0145

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0205

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.535591
# 1       0.524931  0.545218
# 2       0.577541  0.517724
# 3       0.594170  0.572134
# 4       0.596957  0.588112
# ..           ...       ...
# 515     0.272496  0.299789
# 516     0.233016  0.271093
# 517     0.258332  0.236544
# 518     0.250134  0.261395
# 519     0.245951  0.249644
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9945 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 7s 13ms/step - loss: 5.9868e-04 - val_loss: 0.0214
# Epoch 2/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0026 - val_loss: 0.0159
# Epoch 3/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0017 - val_loss: 0.0172
# Epoch 4/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0014 - val_loss: 0.0118
# Epoch 5/50
# 282/282 [==============================] - 3s 9ms/step - loss: 0.0011 - val_loss: 0.0136
# Epoch 6/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.2300e-04 - val_loss: 0.0077
# Epoch 7/50
# 282/282 [==============================] - 3s 10ms/step - loss: 4.3723e-04 - val_loss: 0.0048
# Epoch 8/50
# 282/282 [==============================] - 3s 10ms/step - loss: 2.5460e-04 - val_loss: 0.0031
# Epoch 9/50
# 282/282 [==============================] - 3s 9ms/step - loss: 1.4398e-04 - val_loss: 0.0020
# Epoch 10/50
# 282/282 [==============================] - 3s 9ms/step - loss: 9.1242e-05 - val_loss: 0.0016
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6468e-05 - val_loss: 0.0015
# Epoch 12/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.1593e-05 - val_loss: 0.0015
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9995e-05 - val_loss: 0.0015
# Epoch 14/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9790e-05 - val_loss: 0.0016
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9991e-05 - val_loss: 0.0017
# Epoch 16/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.0243e-05 - val_loss: 0.0019
# Epoch 17/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.0756e-05 - val_loss: 0.0020
# Epoch 18/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1834e-05 - val_loss: 0.0021
# Epoch 19/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3359e-05 - val_loss: 0.0022
# Epoch 20/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.5007e-05 - val_loss: 0.0022
# Epoch 21/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.6445e-05 - val_loss: 0.0022
# Epoch 22/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7511e-05 - val_loss: 0.0022
# Epoch 23/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8279e-05 - val_loss: 0.0021
# Epoch 24/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8904e-05 - val_loss: 0.0020
# Epoch 25/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9498e-05 - val_loss: 0.0020
# Epoch 26/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0089e-05 - val_loss: 0.0019
# Epoch 27/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0645e-05 - val_loss: 0.0018
# Epoch 28/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.1106e-05 - val_loss: 0.0018
# Epoch 29/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.1423e-05 - val_loss: 0.0017
# Epoch 30/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1571e-05 - val_loss: 0.0017
# Epoch 31/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1501e-05 - val_loss: 0.0016
# Epoch 32/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1149e-05 - val_loss: 0.0016
# Epoch 33/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0813e-05 - val_loss: 0.0016
# Epoch 34/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.0417e-05 - val_loss: 0.0015
# Epoch 35/50
# 282/282 [==============================] - 3s 9ms/step - loss: 8.0349e-05 - val_loss: 0.0015
# Epoch 36/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9752e-05 - val_loss: 0.0015
# Epoch 37/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9562e-05 - val_loss: 0.0015
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.9210e-05 - val_loss: 0.0015
# Epoch 39/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9208e-05 - val_loss: 0.0014
# Epoch 40/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.9011e-05 - val_loss: 0.0014
# Epoch 41/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.8940e-05 - val_loss: 0.0014
# Epoch 42/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8453e-05 - val_loss: 0.0014
# Epoch 43/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8544e-05 - val_loss: 0.0014
# Epoch 44/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.8468e-05 - val_loss: 0.0014
# Epoch 45/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.8115e-05 - val_loss: 0.0014
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7402e-05 - val_loss: 0.0014
# Epoch 47/50
# 282/282 [==============================] - 3s 9ms/step - loss: 7.7294e-05 - val_loss: 0.0014
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6862e-05 - val_loss: 0.0014
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6195e-05 - val_loss: 0.0014
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6163e-05 - val_loss: 0.0014

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 5ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.587404  ]
#  [0.59823394]
#  [0.57043475]
#  [0.62250537]
#  [0.63586164]
#  [0.6384738 ]
#  [0.6050783 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 8.0569e-04
# 0.0008056933293119073

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014
# 0.0014185201143845916

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0332

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0014

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0377

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.587404
# 1       0.524931  0.598234
# 2       0.577541  0.570435
# 3       0.594170  0.622505
# 4       0.596957  0.635862
# ..           ...       ...
# 515     0.272496  0.335954
# 516     0.233016  0.306331
# 517     0.258332  0.267940
# 518     0.250134  0.292040
# 519     0.245951  0.284378
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9937 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 12s 23ms/step - loss: 7.6468e-04 - val_loss: 0.0155
# Epoch 2/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0026 - val_loss: 0.0212
# Epoch 3/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0038 - val_loss: 0.0086
# Epoch 4/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0021 - val_loss: 0.0060
# Epoch 5/50
# 282/282 [==============================] - 5s 19ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 6/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.7874e-04 - val_loss: 0.0021
# Epoch 7/50
# 282/282 [==============================] - 5s 19ms/step - loss: 4.5472e-04 - val_loss: 0.0013
# Epoch 8/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.9820e-04 - val_loss: 8.8085e-04
# Epoch 9/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0270e-04 - val_loss: 6.8131e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.9049e-05 - val_loss: 6.2306e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.7565e-05 - val_loss: 6.7048e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.4205e-05 - val_loss: 8.8117e-04
# Epoch 13/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.2964e-05 - val_loss: 0.0014
# Epoch 14/50
# 282/282 [==============================] - 5s 19ms/step - loss: 8.8554e-05 - val_loss: 0.0024
# Epoch 15/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0441e-04 - val_loss: 0.0028
# Epoch 16/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2333e-04 - val_loss: 0.0026
# Epoch 17/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2824e-04 - val_loss: 0.0025
# Epoch 18/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3071e-04 - val_loss: 0.0024
# Epoch 19/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3151e-04 - val_loss: 0.0024
# Epoch 20/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3180e-04 - val_loss: 0.0023
# Epoch 21/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3170e-04 - val_loss: 0.0022
# Epoch 22/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3338e-04 - val_loss: 0.0024
# Epoch 23/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3336e-04 - val_loss: 0.0027
# Epoch 24/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2828e-04 - val_loss: 0.0020
# Epoch 25/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2978e-04 - val_loss: 0.0017
# Epoch 26/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3008e-04 - val_loss: 0.0015
# Epoch 27/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3349e-04 - val_loss: 0.0013
# Epoch 28/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3758e-04 - val_loss: 0.0011
# Epoch 29/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4003e-04 - val_loss: 8.8326e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.4117e-04 - val_loss: 7.4703e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3865e-04 - val_loss: 6.9448e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3240e-04 - val_loss: 7.3276e-04
# Epoch 33/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.2430e-04 - val_loss: 0.0010
# Epoch 34/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1838e-04 - val_loss: 0.0012
# Epoch 35/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1903e-04 - val_loss: 0.0012
# Epoch 36/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1919e-04 - val_loss: 0.0011
# Epoch 37/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2097e-04 - val_loss: 9.2394e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2678e-04 - val_loss: 7.1768e-04
# Epoch 39/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3453e-04 - val_loss: 4.8894e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.6093e-04 - val_loss: 4.6907e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.5281e-04 - val_loss: 5.1297e-04
# Epoch 42/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.3316e-04 - val_loss: 5.2758e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2221e-04 - val_loss: 5.7157e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.1615e-04 - val_loss: 6.4436e-04
# Epoch 45/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1282e-04 - val_loss: 7.2806e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.0987e-04 - val_loss: 7.3774e-04
# Epoch 47/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1011e-04 - val_loss: 6.7503e-04
# Epoch 48/50
# 282/282 [==============================] - 6s 20ms/step - loss: 1.1270e-04 - val_loss: 5.8176e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.2302e-04 - val_loss: 5.3171e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3755e-04 - val_loss: 4.4764e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 2s 10ms/step
# [[0.5516793 ]
#  [0.5600909 ]
#  [0.5324812 ]
#  [0.58441615]
#  [0.60084176]
#  [0.6022644 ]
#  [0.57036567]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 9ms/step - loss: 0.0019
# 0.0018861684948205948

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 9ms/step - loss: 4.4764e-04
# 0.0004476442118175328

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0150

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0212

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.551679
# 1       0.524931  0.560091
# 2       0.577541  0.532481
# 3       0.594170  0.584416
# 4       0.596957  0.600842
# ..           ...       ...
# 515     0.272496  0.305211
# 516     0.233016  0.277803
# 517     0.258332  0.243648
# 518     0.250134  0.266900
# 519     0.245951  0.258943
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9942 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.023417  0.000781  0.027945
# 1  Percobaan 2  0.014521  0.000419  0.020472
# 2  Percobaan 3  0.033177  0.001419  0.037663
# 3  Percobaan 4  0.015005  0.000448  0.021158

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.25)

# menampilkan plot
plt.show()

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.1, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:13:11.54
