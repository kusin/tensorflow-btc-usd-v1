# %% [markdown]
# # Prediction of BTC-USD Price with algorithm GRU-RNN

# %% [markdown]
# ## 1. Deklarasi Pustaka

# %%
# pustaka untuk manipulasi data-frame
import pandas as pd
from pandas import concat
from pandas import read_csv
from pandas import read_excel
from pandas_datareader import DataReader

# pustaka untuk madnipulasi data-array
import numpy as np
from numpy import concatenate
from numpy import array

# pustaka untuk waktu komputasi
import time
from datetime import datetime

# pustaka untuk visualisasi data
import seaborn as sns
from matplotlib import pyplot
from matplotlib import pyplot as plt

# pustaka untuk visualisasi acf dan pacf
import scipy.stats as sc
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
        
# pustaka untuk membuat data latih dan data uji.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# pustaka untuk membuat model prediksi LSTM-RNN
import itertools
import tensorflow as tf
from keras.utils import Sequence
from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.optimizers import Adam, Adamax, RMSprop, SGD

# early stoping
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# pustaka untuk  evaluasi model prediksi
import math
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 2. Akuisisi Data

# %%
# Set waktu komputasi
start = time.time()

# %%
tf.random.set_seed(42)

# %%
# membaca dataset via csv file
dataset = read_csv("dataset/BTC-USD.csv", parse_dates=['Date']);

# %%
# set index tanggal
dataset = dataset.set_index("Date");

# %%
# menampilkan metadata dataset
dataset.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2896 entries, 2014-12-09 to 2022-11-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2896 non-null   float64
#  1   High       2896 non-null   float64
#  2   Low        2896 non-null   float64
#  3   Close      2896 non-null   float64
#  4   Adj Close  2896 non-null   float64
#  5   Volume     2896 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 158.4 KB

# %%
dataset
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-12-09    361.894989    363.066986    344.950989    352.218994
# 2014-12-10    352.204987    352.384003    346.364990    346.364990
# 2014-12-11    344.339996    361.356995    338.763000    350.506012
# 2014-12-12    350.833008    352.983002    349.290985    352.541992
# 2014-12-13    352.381012    352.381012    346.588013    347.376007
# ...                  ...           ...           ...           ...
# 2022-11-08  20600.671875  20664.607422  17603.544922  18541.271484
# 2022-11-09  18543.761719  18590.458984  15682.692383  15880.780273
# 2022-11-10  15883.158203  18054.312500  15834.018555  17586.771484
# 2022-11-11  17583.251953  17650.943359  16543.482422  17034.292969
# 2022-11-12  17066.675781  17066.675781  16659.347656  16752.431641
#
#                Adj Close        Volume
# Date
# 2014-12-09    352.218994      32915500
# 2014-12-10    346.364990      16427700
# 2014-12-11    350.506012      32431300
# 2014-12-12    352.541992      16989800
# 2014-12-13    347.376007      11675900
# ...                  ...           ...
# 2022-11-08  18541.271484  118992465607
# 2022-11-09  15880.780273  102905151606
# 2022-11-10  17586.771484   83202283721
# 2022-11-11  17034.292969   55871616488
# 2022-11-12  16752.431641   50010157056
#
# [2896 rows x 6 columns]

# %% [markdown]
# ## 3. Eksplorasi Datsa Analisis

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, dataset["Open"], color="tab:blue", label="Open Price", linewidth=2)

# membuat label-label
ax1.set_title("Open Price Bitcoin", fontsize=14)
ax1.set_xlabel("Date", fontsize=12)
ax1.set_ylabel("Stock Price", fontsize=12)
ax1.legend(loc='upper left')
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, dataset["Close"], color="tab:green", label="Close Price", linewidth=2)

# membuat label-label
ax2.set_title("Close Price Bitcoin", fontsize=14)
ax2.set_xlabel("Date", fontsize=12)
ax2.set_ylabel("Stock Price", fontsize=12)
ax2.legend(loc='upper left')
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, dataset["High"], color="tab:orange", label="High Price", linewidth=2)

# membuat label-label
ax3.set_title("High Price Bitcoin", fontsize=14)
ax3.set_xlabel("Date", fontsize=12)
ax3.set_ylabel("Stock Price", fontsize=12)
ax3.legend(loc='upper left')
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, dataset["Low"], color="tab:red", label="Low Price", linewidth=2)

# membuat label-label
ax4.set_title("Low Price Bitcoin", fontsize=14)
ax4.set_xlabel("Date", fontsize=12)
ax4.set_ylabel("Stock Price", fontsize=12)
ax4.legend(loc='upper left')
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 4. Praproses Dataset

# %% [markdown]
# - Seleksi Fitur

# %%
# memilih fitur close price
dataset = dataset.filter(['Close']);

# %%
# convert dataframe to series close price
data = dataset.values

# %%
np.round(data[:5],7)
# Out:
# array([[352.218994],
#        [346.36499 ],
#        [350.506012],
#        [352.541992],
#        [347.376007]])

# %%
data.shape
# Out:
# (2896, 1)

# %% [markdown]
# - Normalisasi Data

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1,1))

# %%
np.round(scaled_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
scaled_data.shape
# Out:
# (2896, 1)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(dataset.index.values, scaled_data, color="tab:blue", label="CLose Price", linewidth=2)

# membuat label-label
ax.set_title("Close Price Bitcoin", fontsize=12)
ax.set_xlabel("Date", fontsize=10)
ax.set_ylabel("Stock Price", fontsize=10)
ax.legend(loc='upper left')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# - Data latih dan Data uji

# %%
# split data train and test
train_data, test_data = train_test_split(scaled_data, train_size=0.80, test_size=0.20, shuffle=False)

# %%
# data train
np.round(train_data[:5],7)
# Out:
# array([[0.0025838],
#        [0.0024969],
#        [0.0025583],
#        [0.0025885],
#        [0.0025119]])

# %%
train_data.shape
# Out:
# (2316, 1)

# %%
# data test
np.round(test_data[:5],7)
# Out:
# array([[0.8861327],
#        [0.9397025],
#        [0.9338594],
#        [0.9368913],
#        [0.9110528]])

# %%
test_data.shape
# Out:
# (580, 1)

# %% [markdown]
# - Supervised Learning

# %%
# convert an array of values into a dataset matrix

# function for supervised learning
def create_dataset(look_back, dataset):
    
    # declare variable X and Y
    dataX = []
    dataY = []
    
    # for loop for create supervised learning
    for i in range(look_back, len(dataset)):
        
        # insert value X and Y 
        dataX.append(dataset[i-look_back:i, 0])
        dataY.append(dataset[i, 0])
        
    # return value X and Y
    return np.array(dataX), np.array(dataY)

# %%
# process supervised learning
look_back = 60
x_train, y_train = create_dataset(look_back, train_data)
x_test, y_test = create_dataset(look_back, test_data)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (2256, 60) (2256,)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (520, 60) (520,)

# %%
# reshape input to be [samples, time steps, features]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
print(x_train.shape, x_test.shape)
# Out:
# (2256, 60, 1) (520, 60, 1)

# %% [markdown]
# ## 5. Modeling GRU-RNN

# %% [markdown]
# ### Percobaan 1 - Vanilla GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_1 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1)),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075),
    loss='mean_squared_error'
)

# %%
# fit network
history_1 = model_1.fit(x_train, y_train, batch_size=8, epochs=50, validation_data=(x_test, y_test), verbose=1, use_multiprocessing=True, shuffle=False)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 5s 11ms/step - loss: 3.7878e-04 - val_loss: 0.0073
# Epoch 2/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 3/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.3317e-04 - val_loss: 0.0038
# Epoch 4/50
# 282/282 [==============================] - 3s 10ms/step - loss: 5.5957e-04 - val_loss: 0.0037
# Epoch 5/50
# 282/282 [==============================] - 3s 10ms/step - loss: 4.8648e-04 - val_loss: 0.0032
# Epoch 6/50
# 282/282 [==============================] - 3s 10ms/step - loss: 3.9271e-04 - val_loss: 0.0024
# Epoch 7/50
# 282/282 [==============================] - 3s 10ms/step - loss: 3.1592e-04 - val_loss: 0.0020
# Epoch 8/50
# 282/282 [==============================] - 3s 10ms/step - loss: 2.6441e-04 - val_loss: 0.0018
# Epoch 9/50
# 282/282 [==============================] - 3s 10ms/step - loss: 2.2542e-04 - val_loss: 0.0014
# Epoch 10/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.9201e-04 - val_loss: 0.0013
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.7188e-04 - val_loss: 0.0011
# Epoch 12/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.5343e-04 - val_loss: 0.0011
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.3902e-04 - val_loss: 9.5402e-04
# Epoch 14/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2317e-04 - val_loss: 8.8377e-04
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.0796e-04 - val_loss: 7.9264e-04
# Epoch 16/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.3674e-05 - val_loss: 7.1919e-04
# Epoch 17/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.1555e-05 - val_loss: 6.5597e-04
# Epoch 18/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3312e-05 - val_loss: 6.1749e-04
# Epoch 19/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9139e-05 - val_loss: 6.1029e-04
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.8241e-05 - val_loss: 6.2700e-04
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9193e-05 - val_loss: 6.5244e-04
# Epoch 22/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.0813e-05 - val_loss: 6.7787e-04
# Epoch 23/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2502e-05 - val_loss: 6.9997e-04
# Epoch 24/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3974e-05 - val_loss: 7.1720e-04
# Epoch 25/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5016e-05 - val_loss: 7.3242e-04
# Epoch 26/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6184e-05 - val_loss: 7.4199e-04
# Epoch 27/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6749e-05 - val_loss: 7.4819e-04
# Epoch 28/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7005e-05 - val_loss: 7.5217e-04
# Epoch 29/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.7054e-05 - val_loss: 7.5449e-04
# Epoch 30/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6883e-05 - val_loss: 7.5521e-04
# Epoch 31/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6674e-05 - val_loss: 7.5704e-04
# Epoch 32/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6442e-05 - val_loss: 7.5796e-04
# Epoch 33/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.6036e-05 - val_loss: 7.5844e-04
# Epoch 34/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5820e-05 - val_loss: 7.5957e-04
# Epoch 35/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5505e-05 - val_loss: 7.6017e-04
# Epoch 36/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.5045e-05 - val_loss: 7.6354e-04
# Epoch 37/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.4781e-05 - val_loss: 7.6750e-04
# Epoch 38/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.4726e-05 - val_loss: 7.6980e-04
# Epoch 39/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.4193e-05 - val_loss: 7.7442e-04
# Epoch 40/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3965e-05 - val_loss: 7.8229e-04
# Epoch 41/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.4095e-05 - val_loss: 7.8362e-04
# Epoch 42/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3687e-05 - val_loss: 7.8502e-04
# Epoch 43/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3246e-05 - val_loss: 7.8538e-04
# Epoch 44/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.2946e-05 - val_loss: 7.8881e-04
# Epoch 45/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2620e-05 - val_loss: 7.9047e-04
# Epoch 46/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.2072e-05 - val_loss: 7.9725e-04
# Epoch 47/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1982e-05 - val_loss: 8.0087e-04
# Epoch 48/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1727e-05 - val_loss: 8.0611e-04
# Epoch 49/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1465e-05 - val_loss: 8.0998e-04
# Epoch 50/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.0998e-05 - val_loss: 8.2191e-04

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                7950
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 8,001
# Trainable params: 8,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_1 = model_1.predict(x_test)
# Out:
# 17/17 [==============================] - 0s 5ms/step

# %%
print(predictions_1[:7])
# Out:
# [[0.56466895]
#  [0.5753031 ]
#  [0.545916  ]
#  [0.5989123 ]
#  [0.6142298 ]
#  [0.6191402 ]
#  [0.5859843 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_1.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 1 - Vanilla GRU-RNN)

# %%
scores_1 = model_1.evaluate(x_train, y_train)
scores_1
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 6.7391e-04
# 0.0006739084492437541

# %%
scores_1 = model_1.evaluate(x_test, y_test)
scores_1
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 8.2191e-04
# 0.0008219103910960257

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_1 = mean_absolute_error(y_test, predictions_1)
print('Test MAE : %.4f' % mae_1)
# Out:
# Test MAE : 0.0242

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_1 = mean_squared_error(y_test, predictions_1)
print('Test MSE: %.4f' % mse_1)
# Out:
# Test MSE: 0.0008

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_1 = sqrt(mse_1)
print('Test RMSE: %.4f' % rmse_1)
# Out:
# Test RMSE: 0.0287

# %% [markdown]
# - Corelation pearson

# %%
hasil_1 = np.stack((y_test.reshape(-1), predictions_1.reshape(-1)), axis=1)
hasil_1 = pd.DataFrame(hasil_1, columns = ['data_aktual','prediksi'])
hasil_1
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.564669
# 1       0.524931  0.575303
# 2       0.577541  0.545916
# 3       0.594170  0.598912
# 4       0.596957  0.614230
# ..           ...       ...
# 515     0.272496  0.330515
# 516     0.233016  0.300063
# 517     0.258332  0.260231
# 518     0.250134  0.282293
# 519     0.245951  0.276158
#
# [520 rows x 2 columns]

# %%
r1, p1 = sc.pearsonr(hasil_1["data_aktual"], hasil_1["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r1)+ "dengan signifikansi" +" {:.4f} ".format(p1))
# Out:
# korelasi data akual dengan hasil prediksi 0.9945 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 1 - Vanilla GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_1 = scaler.inverse_transform(predictions_1)

# %%
# shift test predictions for plotting
predictionsPlot_1 = np.empty_like(scaled_data)
predictionsPlot_1[:, :] = np.nan
predictionsPlot_1[(len(dataset) - predictions_1.shape[0]):len(dataset), :] = predictions_1

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 1 - Vanilla GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 2 - Stacked GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_2 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.GRU(units=50, return_sequences=False),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_2.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_2 = model_2.fit(
    x_train, y_train,
    batch_size=8, epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 9s 20ms/step - loss: 7.7874e-04 - val_loss: 0.0223
# Epoch 2/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0033 - val_loss: 0.0272
# Epoch 3/50
# 282/282 [==============================] - 5s 17ms/step - loss: 0.0047 - val_loss: 0.0330
# Epoch 4/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0046 - val_loss: 0.0359
# Epoch 5/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0043 - val_loss: 0.0396
# Epoch 6/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0037 - val_loss: 0.0415
# Epoch 7/50
# 282/282 [==============================] - 5s 18ms/step - loss: 0.0024 - val_loss: 0.0172
# Epoch 8/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.8108e-04 - val_loss: 0.0046
# Epoch 9/50
# 282/282 [==============================] - 5s 18ms/step - loss: 2.5397e-04 - val_loss: 7.8479e-04
# Epoch 10/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.8667e-05 - val_loss: 5.9153e-04
# Epoch 11/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.3315e-05 - val_loss: 5.7174e-04
# Epoch 12/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.2920e-05 - val_loss: 5.7901e-04
# Epoch 13/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.2824e-05 - val_loss: 6.0394e-04
# Epoch 14/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.3427e-05 - val_loss: 6.4624e-04
# Epoch 15/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.4980e-05 - val_loss: 7.0262e-04
# Epoch 16/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.7230e-05 - val_loss: 7.6276e-04
# Epoch 17/50
# 282/282 [==============================] - 5s 18ms/step - loss: 6.9726e-05 - val_loss: 8.2048e-04
# Epoch 18/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.2475e-05 - val_loss: 8.7733e-04
# Epoch 19/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.5667e-05 - val_loss: 9.1039e-04
# Epoch 20/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.8597e-05 - val_loss: 9.0267e-04
# Epoch 21/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.1189e-05 - val_loss: 8.5567e-04
# Epoch 22/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.4216e-05 - val_loss: 7.8757e-04
# Epoch 23/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.8494e-05 - val_loss: 7.2305e-04
# Epoch 24/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.3321e-05 - val_loss: 6.6999e-04
# Epoch 25/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.7163e-05 - val_loss: 6.2723e-04
# Epoch 26/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.9379e-05 - val_loss: 5.9099e-04
# Epoch 27/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0033e-04 - val_loss: 5.5772e-04
# Epoch 28/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0061e-04 - val_loss: 5.2573e-04
# Epoch 29/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0056e-04 - val_loss: 4.9531e-04
# Epoch 30/50
# 282/282 [==============================] - 5s 18ms/step - loss: 1.0027e-04 - val_loss: 4.6791e-04
# Epoch 31/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.9718e-05 - val_loss: 4.4525e-04
# Epoch 32/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.8871e-05 - val_loss: 4.2871e-04
# Epoch 33/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.7696e-05 - val_loss: 4.1891e-04
# Epoch 34/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.6213e-05 - val_loss: 4.1539e-04
# Epoch 35/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.4509e-05 - val_loss: 4.1671e-04
# Epoch 36/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.2734e-05 - val_loss: 4.2082e-04
# Epoch 37/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.1030e-05 - val_loss: 4.2557e-04
# Epoch 38/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.9492e-05 - val_loss: 4.3006e-04
# Epoch 39/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.8173e-05 - val_loss: 4.3426e-04
# Epoch 40/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.7045e-05 - val_loss: 4.3775e-04
# Epoch 41/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.6106e-05 - val_loss: 4.4249e-04
# Epoch 42/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.5621e-05 - val_loss: 4.4284e-04
# Epoch 43/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.5687e-05 - val_loss: 4.4105e-04
# Epoch 44/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.6580e-05 - val_loss: 4.4150e-04
# Epoch 45/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.8099e-05 - val_loss: 4.4766e-04
# Epoch 46/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.8898e-05 - val_loss: 4.4828e-04
# Epoch 47/50
# 282/282 [==============================] - 5s 18ms/step - loss: 9.1935e-05 - val_loss: 4.9750e-04
# Epoch 48/50
# 282/282 [==============================] - 5s 18ms/step - loss: 8.5116e-05 - val_loss: 5.4202e-04
# Epoch 49/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.8137e-05 - val_loss: 4.6619e-04
# Epoch 50/50
# 282/282 [==============================] - 5s 18ms/step - loss: 7.8671e-05 - val_loss: 4.1663e-04

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 60, 50)            7950
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 23,301
# Trainable params: 23,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_2 = model_2.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 8ms/step

# %%
print(predictions_2[:7])
# Out:
# [[0.5347672 ]
#  [0.54510796]
#  [0.5179338 ]
#  [0.5720348 ]
#  [0.58741313]
#  [0.59035414]
#  [0.559334  ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_2.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 2 - Stacked GRU-RNN)

# %%
scores_2 = model_2.evaluate(x_train, y_train)
scores_2
# Out:
# 71/71 [==============================] - 1s 9ms/step - loss: 3.6751e-04
# 0.0003675142943393439

# %%
scores_2 = model_2.evaluate(x_test, y_test)
scores_2
# Out:
# 17/17 [==============================] - 0s 9ms/step - loss: 4.1663e-04
# 0.00041662732837721705

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_2 = mean_absolute_error(y_test, predictions_2)
print('Test MAE : %.4f' % mae_2)
# Out:
# Test MAE : 0.0145

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_2 = mean_squared_error(y_test, predictions_2)
print('Test MSE: %.4f' % mse_2)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_2 = sqrt(mse_2)
print('Test RMSE: %.4f' % rmse_2)
# Out:
# Test RMSE: 0.0204

# %% [markdown]
# - Corelation pearson

# %%
hasil_2 = np.stack((y_test.reshape(-1), predictions_2.reshape(-1)), axis=1)
hasil_2 = pd.DataFrame(hasil_2, columns = ['data_aktual','prediksi'])
hasil_2
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.534767
# 1       0.524931  0.545108
# 2       0.577541  0.517934
# 3       0.594170  0.572035
# 4       0.596957  0.587413
# ..           ...       ...
# 515     0.272496  0.300298
# 516     0.233016  0.271716
# 517     0.258332  0.237040
# 518     0.250134  0.261169
# 519     0.245951  0.249532
#
# [520 rows x 2 columns]

# %%
r2, p2 = sc.pearsonr(hasil_2["data_aktual"], hasil_2["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r2)+ "dengan signifikansi" +" {:.4f} ".format(p2))
# Out:
# korelasi data akual dengan hasil prediksi 0.9946 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 2 - Stacked GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_2 = scaler.inverse_transform(predictions_2)

# %%
# shift test predictions for plotting
predictionsPlot_2 = np.empty_like(scaled_data)
predictionsPlot_2[:, :] = np.nan
predictionsPlot_2[(len(dataset) - predictions_2.shape[0]):len(dataset), :] = predictions_2

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 2 - Stacked GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 3 - Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_3 = tf.keras.Sequential([
    
    # The input layer
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False, input_shape=(x_train.shape[1], 1))
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_3.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_3 = model_3.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 7s 14ms/step - loss: 7.5524e-04 - val_loss: 0.0258
# Epoch 2/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0031 - val_loss: 0.0329
# Epoch 3/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0025 - val_loss: 0.0313
# Epoch 4/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0021 - val_loss: 0.0273
# Epoch 5/50
# 282/282 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0241
# Epoch 6/50
# 282/282 [==============================] - 3s 10ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 7/50
# 282/282 [==============================] - 3s 11ms/step - loss: 6.9276e-04 - val_loss: 0.0073
# Epoch 8/50
# 282/282 [==============================] - 3s 10ms/step - loss: 3.0821e-04 - val_loss: 0.0042
# Epoch 9/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.9166e-04 - val_loss: 0.0031
# Epoch 10/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.5856e-04 - val_loss: 0.0026
# Epoch 11/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.4568e-04 - val_loss: 0.0023
# Epoch 12/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.3765e-04 - val_loss: 0.0021
# Epoch 13/50
# 282/282 [==============================] - 3s 10ms/step - loss: 1.2803e-04 - val_loss: 0.0019
# Epoch 14/50
# 282/282 [==============================] - 3s 11ms/step - loss: 1.1482e-04 - val_loss: 0.0018
# Epoch 15/50
# 282/282 [==============================] - 3s 10ms/step - loss: 9.8864e-05 - val_loss: 0.0017
# Epoch 16/50
# 282/282 [==============================] - 3s 10ms/step - loss: 8.3723e-05 - val_loss: 0.0016
# Epoch 17/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.3436e-05 - val_loss: 0.0017
# Epoch 18/50
# 282/282 [==============================] - 3s 11ms/step - loss: 6.9096e-05 - val_loss: 0.0018
# Epoch 19/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.8603e-05 - val_loss: 0.0020
# Epoch 20/50
# 282/282 [==============================] - 3s 10ms/step - loss: 6.9723e-05 - val_loss: 0.0022
# Epoch 21/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.1480e-05 - val_loss: 0.0023
# Epoch 22/50
# 282/282 [==============================] - 3s 10ms/step - loss: 7.3563e-05 - val_loss: 0.0024
# Epoch 23/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.5631e-05 - val_loss: 0.0024
# Epoch 24/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.7468e-05 - val_loss: 0.0023
# Epoch 25/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9081e-05 - val_loss: 0.0023
# Epoch 26/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0543e-05 - val_loss: 0.0022
# Epoch 27/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1868e-05 - val_loss: 0.0021
# Epoch 28/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.2989e-05 - val_loss: 0.0020
# Epoch 29/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.3800e-05 - val_loss: 0.0019
# Epoch 30/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.4205e-05 - val_loss: 0.0018
# Epoch 31/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.4186e-05 - val_loss: 0.0018
# Epoch 32/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.3806e-05 - val_loss: 0.0017
# Epoch 33/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.3164e-05 - val_loss: 0.0016
# Epoch 34/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.2408e-05 - val_loss: 0.0016
# Epoch 35/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.1642e-05 - val_loss: 0.0015
# Epoch 36/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0944e-05 - val_loss: 0.0015
# Epoch 37/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0246e-05 - val_loss: 0.0015
# Epoch 38/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.0020e-05 - val_loss: 0.0015
# Epoch 39/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9818e-05 - val_loss: 0.0015
# Epoch 40/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9624e-05 - val_loss: 0.0015
# Epoch 41/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9975e-05 - val_loss: 0.0015
# Epoch 42/50
# 282/282 [==============================] - 3s 11ms/step - loss: 8.0115e-05 - val_loss: 0.0015
# Epoch 43/50
# 282/282 [==============================] - 3s 12ms/step - loss: 8.0299e-05 - val_loss: 0.0015
# Epoch 44/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.9844e-05 - val_loss: 0.0015
# Epoch 45/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.8948e-05 - val_loss: 0.0015
# Epoch 46/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.8617e-05 - val_loss: 0.0014
# Epoch 47/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.7959e-05 - val_loss: 0.0014
# Epoch 48/50
# 282/282 [==============================] - 3s 12ms/step - loss: 7.7512e-05 - val_loss: 0.0014
# Epoch 49/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.7191e-05 - val_loss: 0.0015
# Epoch 50/50
# 282/282 [==============================] - 3s 11ms/step - loss: 7.6947e-05 - val_loss: 0.0015

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (8, 100)                 15900
#  l)
#
#  dense_2 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_3 = model_3.predict(x_test)
# Out:
# 17/17 [==============================] - 1s 6ms/step

# %%
print(predictions_3[:7])
# Out:
# [[0.5924542 ]
#  [0.60385907]
#  [0.57564497]
#  [0.6278348 ]
#  [0.641216  ]
#  [0.6428901 ]
#  [0.60869217]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_3.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 3 - Bidirectional GRU-RNN)

# %%
scores_3 = model_3.evaluate(x_train, y_train)
scores_3
# Out:
# 71/71 [==============================] - 1s 6ms/step - loss: 6.9320e-04
# 0.0006932037067599595

# %%
scores_3 = model_3.evaluate(x_test, y_test)
scores_3
# Out:
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0015
# 0.0014527231687679887

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_3 = mean_absolute_error(y_test, predictions_3)
print('Test MAE : %.4f' % mae_3)
# Out:
# Test MAE : 0.0334

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_3 = mean_squared_error(y_test, predictions_3)
print('Test MSE: %.4f' % mse_3)
# Out:
# Test MSE: 0.0015

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_3 = sqrt(mse_3)
print('Test RMSE: %.4f' % rmse_3)
# Out:
# Test RMSE: 0.0381

# %% [markdown]
# - Corelation pearson

# %%
hasil_3 = np.stack((y_test.reshape(-1), predictions_3.reshape(-1)), axis=1)
hasil_3 = pd.DataFrame(hasil_3, columns = ['data_aktual','prediksi'])
hasil_3
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.592454
# 1       0.524931  0.603859
# 2       0.577541  0.575645
# 3       0.594170  0.627835
# 4       0.596957  0.641216
# ..           ...       ...
# 515     0.272496  0.333964
# 516     0.233016  0.304066
# 517     0.258332  0.265535
# 518     0.250134  0.289813
# 519     0.245951  0.281880
#
# [520 rows x 2 columns]

# %%
r3, p3 = sc.pearsonr(hasil_3["data_aktual"], hasil_3["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r3)+ "dengan signifikansi" +" {:.4f} ".format(p3))
# Out:
# korelasi data akual dengan hasil prediksi 0.9933 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 3 - Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_3 = scaler.inverse_transform(predictions_3)

# %%
# shift test predictions for plotting
predictionsPlot_3 = np.empty_like(scaled_data)
predictionsPlot_3[:, :] = np.nan
predictionsPlot_3[(len(dataset) - predictions_3.shape[0]):len(dataset), :] = predictions_3

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 3 - Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ### Percobaan 4 - Stacked-Bidirectional GRU-RNN

# %%
tf.random.set_seed(42)

# %%
# The GRU-RNN architecture
model_4 = tf.keras.Sequential([
    
    # First GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1))
    ),
    
    # Secound GRU layer with Dropout regularisation
    tf.keras.layers.Bidirectional(
        tf.keras.layers.GRU(units=50, return_sequences=False)
    ),
    
    # The output layer
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model GRU
model_4.compile(optimizer='adam', loss='mean_squared_error')

# %%
# fit network
history_4 = model_4.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=1,
    use_multiprocessing=True,
    shuffle=False
)
# Out:
# Epoch 1/50
# 282/282 [==============================] - 15s 27ms/step - loss: 5.8162e-04 - val_loss: 0.0125
# Epoch 2/50
# 282/282 [==============================] - 6s 23ms/step - loss: 0.0019 - val_loss: 0.0191
# Epoch 3/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0026 - val_loss: 0.0051
# Epoch 4/50
# 282/282 [==============================] - 6s 22ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 5/50
# 282/282 [==============================] - 6s 23ms/step - loss: 3.6481e-04 - val_loss: 5.8655e-04
# Epoch 6/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.2163e-04 - val_loss: 5.6538e-04
# Epoch 7/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.0356e-05 - val_loss: 4.4974e-04
# Epoch 8/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.3871e-05 - val_loss: 4.3784e-04
# Epoch 9/50
# 282/282 [==============================] - 6s 22ms/step - loss: 8.4417e-05 - val_loss: 5.2131e-04
# Epoch 10/50
# 282/282 [==============================] - 7s 23ms/step - loss: 8.8430e-05 - val_loss: 7.8587e-04
# Epoch 11/50
# 282/282 [==============================] - 6s 22ms/step - loss: 9.4887e-05 - val_loss: 0.0013
# Epoch 12/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.0933e-04 - val_loss: 0.0019
# Epoch 13/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3073e-04 - val_loss: 0.0020
# Epoch 14/50
# 282/282 [==============================] - 5s 19ms/step - loss: 1.3823e-04 - val_loss: 0.0021
# Epoch 15/50
# 282/282 [==============================] - 6s 21ms/step - loss: 1.3938e-04 - val_loss: 0.0022
# Epoch 16/50
# 282/282 [==============================] - 6s 22ms/step - loss: 1.3737e-04 - val_loss: 0.0022
# Epoch 17/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.3900e-04 - val_loss: 0.0023
# Epoch 18/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.3524e-04 - val_loss: 0.0024
# Epoch 19/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.3400e-04 - val_loss: 0.0022
# Epoch 20/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.3322e-04 - val_loss: 0.0019
# Epoch 21/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.3428e-04 - val_loss: 0.0018
# Epoch 22/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.3407e-04 - val_loss: 0.0016
# Epoch 23/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.3558e-04 - val_loss: 0.0014
# Epoch 24/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.3997e-04 - val_loss: 0.0012
# Epoch 25/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.4342e-04 - val_loss: 9.8692e-04
# Epoch 26/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.4712e-04 - val_loss: 8.3722e-04
# Epoch 27/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.4514e-04 - val_loss: 7.4874e-04
# Epoch 28/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.3816e-04 - val_loss: 8.6991e-04
# Epoch 29/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.2559e-04 - val_loss: 9.6092e-04
# Epoch 30/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.1702e-04 - val_loss: 0.0011
# Epoch 31/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.1840e-04 - val_loss: 0.0012
# Epoch 32/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.2041e-04 - val_loss: 0.0012
# Epoch 33/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.2241e-04 - val_loss: 0.0011
# Epoch 34/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.2330e-04 - val_loss: 9.7462e-04
# Epoch 35/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.3013e-04 - val_loss: 7.9928e-04
# Epoch 36/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.4375e-04 - val_loss: 5.6414e-04
# Epoch 37/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.6509e-04 - val_loss: 4.5712e-04
# Epoch 38/50
# 282/282 [==============================] - 6s 23ms/step - loss: 1.7624e-04 - val_loss: 4.7554e-04
# Epoch 39/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.6589e-04 - val_loss: 4.3953e-04
# Epoch 40/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.6361e-04 - val_loss: 4.3564e-04
# Epoch 41/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.4574e-04 - val_loss: 4.7027e-04
# Epoch 42/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.2403e-04 - val_loss: 5.5550e-04
# Epoch 43/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.0995e-04 - val_loss: 6.7643e-04
# Epoch 44/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.0402e-04 - val_loss: 7.7526e-04
# Epoch 45/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.0383e-04 - val_loss: 8.1397e-04
# Epoch 46/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.0425e-04 - val_loss: 7.6704e-04
# Epoch 47/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.0598e-04 - val_loss: 6.5161e-04
# Epoch 48/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.1510e-04 - val_loss: 5.4702e-04
# Epoch 49/50
# 282/282 [==============================] - 7s 24ms/step - loss: 1.3350e-04 - val_loss: 4.9285e-04
# Epoch 50/50
# 282/282 [==============================] - 7s 23ms/step - loss: 1.5810e-04 - val_loss: 4.4561e-04

# %%
model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (8, 60, 100)             15900
#  nal)
#
#  bidirectional_2 (Bidirectio  (8, 100)                 45600
#  nal)
#
#  dense_3 (Dense)             (8, 1)                    101
#
# =================================================================
# Total params: 61,601
# Trainable params: 61,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions_4 = model_4.predict(x_test)
print(predictions_4[:7])
# Out:
# 17/17 [==============================] - 3s 11ms/step
# [[0.5498389 ]
#  [0.559854  ]
#  [0.53212404]
#  [0.58461237]
#  [0.5995638 ]
#  [0.60134405]
#  [0.5701156 ]]

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(history_4.history['loss'], color="tab:blue", label="loss func", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Grafik Loss Function", fontsize=14)
ax.set_xlabel("epoch", fontsize=10)
ax.set_ylabel("loss function", fontsize=10)
ax.legend(loc='upper right')
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# #### Evaluasi Model (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
scores_4 = model_4.evaluate(x_train, y_train)
scores_4
# Out:
# 71/71 [==============================] - 2s 11ms/step - loss: 0.0021
# 0.002129407599568367

# %%
scores_4 = model_4.evaluate(x_test, y_test)
scores_4
# Out:
# 17/17 [==============================] - 0s 12ms/step - loss: 4.4561e-04
# 0.00044561189133673906

# %% [markdown]
# - MAE (Mean Absolute Error)

# %%
mae_4 = mean_absolute_error(y_test, predictions_4)
print('Test MAE : %.4f' % mae_4)
# Out:
# Test MAE : 0.0153

# %% [markdown]
# - MSE (Mean Squared Error)

# %%
mse_4 = mean_squared_error(y_test, predictions_4)
print('Test MSE: %.4f' % mse_4)
# Out:
# Test MSE: 0.0004

# %% [markdown]
# - RMSE (Root Mean Squared Error)

# %%
rmse_4 = sqrt(mse_4)
print('Test RMSE: %.4f' % rmse_4)
# Out:
# Test RMSE: 0.0211

# %% [markdown]
# - Corelation pearson

# %%
hasil_4 = np.stack((y_test.reshape(-1), predictions_4.reshape(-1)), axis=1)
hasil_4 = pd.DataFrame(hasil_4, columns = ['data_aktual','prediksi'])
hasil_4
# Out:
#      data_aktual  prediksi
# 0       0.551373  0.549839
# 1       0.524931  0.559854
# 2       0.577541  0.532124
# 3       0.594170  0.584612
# 4       0.596957  0.599564
# ..           ...       ...
# 515     0.272496  0.307969
# 516     0.233016  0.280536
# 517     0.258332  0.246307
# 518     0.250134  0.271285
# 519     0.245951  0.261400
#
# [520 rows x 2 columns]

# %%
r4, p4 = sc.pearsonr(hasil_4["data_aktual"], hasil_4["prediksi"])
print("korelasi data akual dengan hasil prediksi" +" {:.4f} ".format(r4)+ "dengan signifikansi" +" {:.4f} ".format(p4))
# Out:
# korelasi data akual dengan hasil prediksi 0.9942 dengan signifikansi 0.0000

# %% [markdown]
# #### Visualisasi Data (Percobaan 4 - Stacked-Bidirectional GRU-RNN)

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (10,5))

# membuat time series plot
ax.plot(y_test, color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(predictions_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.legend(loc="best")
ax.grid(True)

# menampilka
plt.show()

# %%
# inverse value test predictions
predictions_4 = scaler.inverse_transform(predictions_4)

# %%
# shift test predictions for plotting
predictionsPlot_4 = np.empty_like(scaled_data)
predictionsPlot_4[:, :] = np.nan
predictionsPlot_4[(len(dataset) - predictions_4.shape[0]):len(dataset), :] = predictions_4

# %%
# membuat frame
fig, ax = plt.subplots(figsize = (15,5))

# membuat time series plot
ax.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax.set_title("Percobaan 4 - Stacked-Bidirectional GRU-RNN", fontsize=14)
ax.set_xlabel("Years", fontsize=10)
ax.set_ylabel("Price BTC-USD", fontsize=10)
ax.legend(loc="best")
ax.grid(True)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 6. Evaluasi Model Vanilla, Stacked, Bidirectional GRU-RNN

# %%
hasil_4 = pd.DataFrame({
    'Percobaan' : ['Percobaan 1', 'Percobaan 2', 'Percobaan 3', 'Percobaan 4'],
    'MAE' : [mae_1, mae_2, mae_3, mae_4],
    'MSE' : [mse_1, mse_2, mse_3, mse_4],
    'RMSE' : [rmse_1, rmse_2, rmse_3, rmse_4],
})

# %%
hasil_4
# Out:
#      Percobaan       MAE       MSE      RMSE
# 0  Percobaan 1  0.024213  0.000822  0.028669
# 1  Percobaan 2  0.014480  0.000417  0.020411
# 2  Percobaan 3  0.033449  0.001453  0.038115
# 3  Percobaan 4  0.015279  0.000446  0.021110

# %%
x = np.arange(len(hasil_4["Percobaan"]))
width = 0.35

# %%
fig, ax = plt.subplots()
ax.bar(x - width/2, hasil_4["MAE"], width, label='MAE')
ax.bar(x + width/2, hasil_4["RMSE"], width, label='RMSE')
 
#ax.set_xlabel('Year')
ax.set_title('Nilai MAE dan RMSE')
ax.set_xticks(x, hasil_4["Percobaan"])
ax.legend()
 
plt.show()

# %% [markdown]
# ## 7. Visualisasi Data Vanilla, Stacked, Bidirectional LSTM-RNN

# %%
# membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(history_1.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.set_xlabel("epoch", fontsize=10)
ax1.set_ylabel("loss function", fontsize=10)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(history_2.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.set_xlabel("epoch", fontsize=10)
ax2.set_ylabel("loss function", fontsize=10)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(history_3.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.set_xlabel("epoch", fontsize=10)
ax3.set_ylabel("loss function", fontsize=10)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(history_4.history['loss'], color="tab:blue", label="loss function", linewidth=2)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.set_xlabel("epoch", fontsize=10)
ax4.set_ylabel("loss function", fontsize=10)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %%
##### membuat frame
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, facecolor="#f0f0f0", figsize=(20, 10))

# membuat time series plot
ax1.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax1.plot(dataset.index.values, predictionsPlot_1, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax1.set_title("Percobaan 1 - Model Vanilla GRU-RNN", fontsize=14)
ax1.legend(loc="best")
ax1.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax2.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax2.plot(dataset.index.values, predictionsPlot_2, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax2.set_title("Percobaan 2 - Model Stacked GRU-RNN", fontsize=14)
ax2.legend(loc="best")
ax2.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax3.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax3.plot(dataset.index.values, predictionsPlot_3, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax3.set_title("Percobaan 3 - Model Bidirectional GRU-RNN", fontsize=14)
ax3.legend(loc="best")
ax3.grid(True)
# ----------------------------------------------------------------------------------------------------

# membuat time series plot
ax4.plot(dataset.index.values, scaler.inverse_transform(scaled_data), color="tab:blue", label="data aktual", linewidth=2.5)
ax4.plot(dataset.index.values, predictionsPlot_4, color="tab:red", label="data prediksi", linewidth=2.5)

# membuat label-label
ax4.set_title("Percobaan 4 - Model Stacked-Bidirectional GRU-RNN", fontsize=14)
ax4.legend(loc="best")
ax4.grid(True)
# ----------------------------------------------------------------------------------------------------

# set the spacing between subplots
plt.subplots_adjust(wspace=0.15, hspace=0.25)

# menampilkan plot
plt.show()

# %% [markdown]
# ## 8. Complexity time

# %%
# Set akhir waktu komputasi 
end = time.time()

# %%
# Proses menghitung waktu komputasi
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)

# %%
# Hasil waktu komputasi
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:15:10.79
